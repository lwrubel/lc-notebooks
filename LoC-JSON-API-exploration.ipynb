# %% [markdown]
# # A few initial takeaways from using the LC JSON API

# %% [markdown]
# I was trying out [Shawn Averkamp's code](https://github.com/saverkamp/loc-talk-2017/blob/master/womens-suffrage-collections-data/scripts/getLocMods.py) for collecting MODS records for items in LC digital collections and was having trouble getting results for a collection different from the one she worked with (National American Woman Suffrage Association). What was happening?

# %% [markdown]
# In order to get a MODS record for each item in a collection, you need the item's identifier (e.g. 18012004) for constructing a URL for the MODS record. It appears that not all collections have an "item_id" field with the identifier. But let's explore this to see.

# %% [markdown]
# ## Requesting item identifiers
#
# To look at an example, here's some Python code to **request item IDs from a specific collection**. It retrieves two fields that appear to hold id info.

# %%
import requests

# %%
def get_item_ids(coll_name):
    call = requests.get("https://www.loc.gov/collections/{0}?fo=json".format(coll_name))
    data = call.json()
    results = data['results']
    for result in results:
        print(result.get("item_id"), result["id"])

# %% [markdown]
# First, let's see what is in those fields in the National American Woman Suffrage Association collection.

# %%
collection = "national-american-woman-suffrage-association"
get_item_ids(collection)
# Out:
# 18012004/ http://www.loc.gov/item/18012004/
# 33001926/ http://www.loc.gov/item/33001926/
# 23017479/ http://www.loc.gov/item/23017479/
# 15024465/ http://www.loc.gov/item/15024465/
# 08004839/ http://www.loc.gov/item/08004839/
# 08034439/ http://www.loc.gov/item/08034439/
# ca26000179/ http://www.loc.gov/item/ca26000179/
# 28018616/ http://www.loc.gov/item/28018616/
# 28018623/ http://www.loc.gov/item/28018623/
# 28018620/ http://www.loc.gov/item/28018620/
# tmp83029911/ http://www.loc.gov/item/tmp83029911/
# 37017721/ http://www.loc.gov/item/37017721/
# 24029000/ http://www.loc.gov/item/24029000/
# 15007485/ http://www.loc.gov/item/15007485/
# 29012783/ http://www.loc.gov/item/29012783/
# 33003563/ http://www.loc.gov/item/33003563/
# 15008748/ http://www.loc.gov/item/15008748/
# 27007548/ http://www.loc.gov/item/27007548/
# 86182880/ http://www.loc.gov/item/86182880/
# 09002749/ http://www.loc.gov/item/09002749/
# 09002748/ http://www.loc.gov/item/09002748/
# 09002744/ http://www.loc.gov/item/09002744/
# 04037023/ http://www.loc.gov/item/04037023/
# tmp82091485/ http://www.loc.gov/item/tmp82091485/
# 09008216/ http://www.loc.gov/item/09008216/

# %% [markdown]
# Now let's compare with another collection, Baseball Cards:

# %%
collection = "baseball-cards"
get_item_ids(collection)
# Out:
# None http://www.loc.gov/collections/baseball-cards/about-this-collection/
# None http://www.loc.gov/item/2007678540/
# None http://www.loc.gov/item/2007678541/
# None http://www.loc.gov/item/2007678542/
# None http://www.loc.gov/item/2007678545/
# None http://www.loc.gov/item/2007678537/
# None http://www.loc.gov/item/2007678538/
# None http://www.loc.gov/item/2007677698/
# None http://www.loc.gov/item/2007680699/
# None http://www.loc.gov/item/2007677699/
# None http://www.loc.gov/item/2007680750/
# None http://www.loc.gov/item/2007680759/
# None http://www.loc.gov/item/2007680760/
# None http://www.loc.gov/item/2007680761/
# None http://www.loc.gov/item/2007680762/
# None http://www.loc.gov/item/2007680763/
# None http://www.loc.gov/item/2007680764/
# None http://www.loc.gov/item/2007680765/
# None http://www.loc.gov/item/2007680766/
# None http://www.loc.gov/item/2007680767/
# None http://www.loc.gov/item/2007680768/
# None http://www.loc.gov/item/2007680751/
# None http://www.loc.gov/item/2007680769/
# None http://www.loc.gov/item/2007680771/
# None http://www.loc.gov/item/2007680770/

# %% [markdown]
# Looking at the results from those two collections, we can see that:
# * The Womens Suffrage collection **has an "item id"** with the item number an "id" with the URL for the item
# * The Baseball Cards collection **does not have an "item_id" field**, just the "id" field.

# %% [markdown]
# ## Getting a list of collection names
# What if we wanted to check which identifier fields each collection uses? To check each collection, we first have to get a list of all of the collections.

# %%
def get_collection_names(url, coll_list=[]): 
    call = requests.get(url)
    data = call.json()
    results = data["results"]   
    for result in results:
        coll = result.get("items")
        coll_list.append(coll)
    if data["pagination"]["next"] is not None: #make sure we haven't hit the end of the pages
        next_url = data["pagination"]["next"]
        get_collections(next_url, coll_list)
    
    return coll_list

url = "https://www.loc.gov/collections/?fo=json"
list_of_collections = get_collection_names(url)

# %% [markdown]
# How many collection URLs did we end up with?

# %%
len(list_of_collections)
# Out:
# 307

# %% [markdown]
# Let's take a look at the list of collection URLs we ended up with:

# %%
list_of_collections
# Out:
# ['https://www.loc.gov/collections/aaron-copland/',
#  'https://www.loc.gov/collections/abdul-hamid-ii/',
#  'https://www.loc.gov/collections/abraham-lincoln-papers/',
#  'https://www.loc.gov/collections/afghanistan-web-archive/',
#  'http://memory.loc.gov/ammem/aap/aaphome.html',
#  'https://www.loc.gov/collections/african-american-photographs-1900-paris-exposition/',
#  'https://www.loc.gov/collections/african-american-band-music/',
#  'http://memory.loc.gov/ammem/afcphhtml/afcphhome.html',
#  'https://www.loc.gov/collections/alan-lomax-manuscripts/',
#  'https://www.loc.gov/collections/alan-lomax-in-michigan/',
#  'https://www.loc.gov/collections/albert-schatz/',
#  'https://www.loc.gov/collections/alexander-graham-bell-papers/',
#  'https://www.loc.gov/collections/alexander-hamilton-papers/',
#  'https://www.loc.gov/collections/alexander-hamilton-stephens-papers/',
#  'https://www.loc.gov/collections/alfred-whital-stern-lincolniana/',
#  'https://www.loc.gov/collections/amazing-grace/',
#  'https://www.loc.gov/collections/america-at-work-and-leisure-1894-to-1915/',
#  'https://www.loc.gov/collections/nineteenth-century-song-sheets/',
#  'https://www.loc.gov/collections/dance-instruction-manuals-from-1490-to-1920/',
#  'https://www.loc.gov/collections/american-choral-music/',
#  'https://www.loc.gov/collections/american-colony-in-jerusalem/',
#  'https://www.loc.gov/collections/american-english-dialect-recordings-from-the-center-for-applied-linguistics/',
#  'https://www.loc.gov/collections/world-war-i-and-1920-election-recordings/',
#  'https://www.loc.gov/collections/federal-writers-project/',
#  'https://www.loc.gov/collections/travels-in-america-1750-to-1920/',
#  'https://www.loc.gov/collections/american-revolutionary-war-maps/',
#  'http://memory.loc.gov/ammem/vshtml/vshome.html',
#  'https://www.loc.gov/collections/andrew-jackson-papers/',
#  'https://www.loc.gov/collections/anna-maria-brodeau-thornton-papers/',
#  'https://www.loc.gov/collections/ansel-adams-manzanar/',
#  'https://www.loc.gov/collections/architecture-design-and-engineering-drawings/',
#  'https://www.loc.gov/collections/archive-of-hispanic-literature-on-tape/',
#  'https://www.loc.gov/collections/archive-of-recorded-poetry-and-literature/',
#  'https://www.loc.gov/collections/bain/',
#  'https://www.loc.gov/collections/ballets-russes-de-serge-diaghilev/',
#  'https://www.loc.gov/collections/civil-war-band-music/',
#  'https://www.loc.gov/collections/baseball-cards/',
#  'https://www.loc.gov/collections/baseball-sheet-music/',
#  'https://www.loc.gov/collections/san-francisco-earthquake-and-fire-1897-to-1916/',
#  'https://www.loc.gov/collections/slave-narratives-from-the-federal-writers-project-1936-to-1938/',
#  'https://www.loc.gov/collections/brady-handy/',
#  'https://www.loc.gov/collections/brazil-cordel-literature-web-archive/',
#  'https://www.loc.gov/collections/brazilian-presidential-election-2010-web-archive/',
#  'https://www.loc.gov/collections/bronislava-nijinska/',
#  'https://www.loc.gov/collections/brumfield/',
#  'https://www.loc.gov/collections/ranching-culture-in-northern-nevada-from-1945-to-1982/',
#  'https://www.loc.gov/collections/burma-myanmar-general-election-2010-web-archive/',
#  'https://www.loc.gov/collections/jackie-robinson-baseball/',
#  'https://www.loc.gov/collections/cabinet-of-american-illustration/',
#  'https://www.loc.gov/collections/california-first-person-narratives/',
#  'https://www.loc.gov/collections/sidney-robertson-cowell-northern-california-folk-music/',
#  'https://www.loc.gov/collections/cambini-collection/',
#  'https://www.loc.gov/collections/washington-and-chesapeake-bay-narratives/',
#  'https://www.loc.gov/collections/captain-pearl-r-nye-life-on-the-erie-and-ohio-canal/',
#  'https://www.loc.gov/collections/carnegie-hall-conversations-with-composers/',
#  'https://www.loc.gov/collections/carnegie-survey-architecture-of-the-south/',
#  'https://www.loc.gov/collections/carpenter/',
#  'https://www.loc.gov/collections/cartoon-drawings/',
#  'https://www.loc.gov/collections/herblock-cartoon-drawings/',
#  'https://www.loc.gov/collections/cartoon-drawings-swann/',
#  'https://www.loc.gov/collections/american-cartoon-prints/',
#  'https://www.loc.gov/collections/british-cartoon-prints/',
#  'https://www.loc.gov/collections/case-books/',
#  'http://memory.loc.gov/ammem/amlaw/lawhome.html',
#  'https://www.loc.gov/collections/charles-reed/',
#  'https://www.loc.gov/collections/chicago-ethnic-arts-project/',
#  'http://chroniclingamerica.loc.gov/',
#  'https://www.loc.gov/collections/cities-and-towns/',
#  'https://www.loc.gov/collections/civil-rights-history-project/',
#  'https://www.loc.gov/collections/civil-war/',
#  'https://www.loc.gov/collections/civil-war-glass-negatives/',
#  'https://www.loc.gov/collections/civil-war-maps/',
#  'https://www.loc.gov/collections/civil-war-sheet-music/',
#  'https://www.loc.gov/collections/tilton-c-reynolds-papers/',
#  'https://www.loc.gov/collections/clara-barton-papers/',
#  'https://www.loc.gov/collections/college-womens-association-of-japan-print-show/',
#  'https://www.loc.gov/collections/confederate-states-of-america-records/',
#  'https://www.loc.gov/collections/coptic-orthodox-liturgical-chant/',
#  'https://www.loc.gov/collections/country-studies/',
#  'https://www.loc.gov/collections/crisis-in-darfur-2006-web-archive/',
#  'https://www.loc.gov/collections/edward-s-curtis/',
#  'https://www.loc.gov/collections/daguerreotypes/',
#  'https://www.loc.gov/collections/danny-kaye-and-sylvia-fine/',
#  'https://www.loc.gov/collections/dayton-c-miller-collection/',
#  'https://www.loc.gov/collections/detroit-publishing-company/',
#  'https://www.loc.gov/collections/discovery-and-exploration/',
#  'https://www.loc.gov/collections/continental-congress-and-constitutional-convention-from-1774-to-1789/',
#  'https://www.loc.gov/collections/dolly-parton-and-the-roots-of-country-music/',
#  'https://www.loc.gov/collections/documentary-drawings/',
#  'https://www.loc.gov/collections/master-drawings/',
#  'https://www.loc.gov/collections/early-american-sheet-music/',
#  'https://www.loc.gov/collections/edwin-mcmasters-stanton-papers/',
#  'https://www.loc.gov/collections/egypt-2008-web-archive/',
#  'https://www.loc.gov/collections/elliott-carter/',
#  'https://www.loc.gov/collections/emile-berliner/',
#  'https://www.loc.gov/collections/ernest-bloch/',
#  'http://memory.loc.gov/ammem/amrvhtml/conshome.html',
#  'https://www.loc.gov/collections/fsa-owi-black-and-white-negatives/',
#  'https://www.loc.gov/collections/fsa-owi-color-photographs/',
#  'https://www.loc.gov/collections/federal-courts-web-archive/',
#  'https://www.loc.gov/collections/federal-register/',
#  'https://www.loc.gov/collections/felix-mendelssohn/',
#  'https://www.loc.gov/collections/fenton-crimean-war-photographs/',
#  'https://www.loc.gov/collections/henry-reed-fiddle-tunes/',
#  'https://www.loc.gov/collections/finding-our-place-in-the-cosmos-with-carl-sagan/',
#  'https://www.loc.gov/collections/fine-prints/',
#  'https://www.loc.gov/collections/japanese-fine-prints-pre-1915/',
#  'https://www.loc.gov/collections/florida-folklife-from-the-works-progress-administration/',
#  'https://www.loc.gov/collections/franklin-pierce-papers/',
#  'https://www.loc.gov/collections/franz-liszt-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/frederick-douglass-papers/',
#  'https://www.loc.gov/collections/freedoms-fortress/',
#  'http://memory.loc.gov/ammem/aapchtml/aapchome.html',
#  'https://www.loc.gov/collections/foreign-affairs-oral-history/',
#  'https://www.loc.gov/collections/general-maps/',
#  'https://www.loc.gov/collections/genthe/',
#  'https://www.loc.gov/collections/george-s-patton-diaries/',
#  'https://www.loc.gov/collections/george-washington-papers/',
#  'https://www.loc.gov/collections/gerry-mulligan/',
#  'https://www.loc.gov/collections/gladstone-african-american-photographs/',
#  'https://www.loc.gov/collections/goldstein-foundation-prints-and-drawings/',
#  'https://www.loc.gov/collections/gottscho-schleisner/',
#  'https://www.loc.gov/collections/grabill/',
#  'https://www.loc.gov/collections/great-conversations-in-music/',
#  'https://www.loc.gov/collections/groups-of-images/',
#  'https://www.loc.gov/collections/guide-records/',
#  'http://memory.loc.gov/ammem/arendthtml/arendthome.html',
#  'https://www.loc.gov/collections/harris-ewing/',
#  'https://www.loc.gov/collections/hidden-treasures-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/carol-m-highsmith/',
#  'https://www.loc.gov/collections/hispano-music-and-culture-from-the-northern-rio-grande/',
#  'https://www.loc.gov/collections/historic-american-buildings-landscapes-and-engineering-records/',
#  'https://www.loc.gov/collections/historic-sheet-music/',
#  'https://www.loc.gov/collections/music-of-nineteenth-century-ohio/',
#  'https://www.loc.gov/collections/horydczak/',
#  'https://www.loc.gov/collections/hotchkiss-maps/',
#  'https://www.loc.gov/collections/ilka-kolsky-artwork/',
#  'https://www.loc.gov/collections/indian-general-election-2009-web-archive/',
#  'https://www.loc.gov/collections/indonesian-general-election-2009-web-archive/',
#  'https://www.loc.gov/collections/films-of-westinghouse-works-1904/',
#  'https://www.loc.gov/collections/international-tribunals-web-archive/',
#  'https://www.loc.gov/collections/edison-company-motion-pictures-and-sound-recordings/',
#  'https://www.loc.gov/collections/iraq-war-2003-web-archive/',
#  'https://www.loc.gov/collections/irving-fine/',
#  'https://www.loc.gov/collections/sheet-music-from-stage-and-screen/',
#  'https://www.loc.gov/collections/james-k-polk-papers/',
#  'https://www.loc.gov/collections/james-madison-papers/',
#  'https://www.loc.gov/collections/james-monroe-papers/',
#  'https://www.loc.gov/collections/japanese-american-internment-camp-newspapers/',
#  'https://www.loc.gov/collections/jazz-on-screen-filmography/',
#  'https://www.loc.gov/collections/jedediah-hotchkiss-papers/',
#  'https://www.loc.gov/collections/joe-smith/',
#  'https://www.loc.gov/collections/john-pershing-papers/',
#  'https://www.loc.gov/collections/john-tyler-papers/',
#  'https://www.loc.gov/collections/frances-benjamin-johnston/',
#  'https://www.loc.gov/collections/korab/',
#  'https://www.loc.gov/collections/lamb-studio/',
#  'https://www.loc.gov/collections/laotian-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/lars-schmidt/',
#  'https://www.loc.gov/collections/mckinley-and-the-pan-american-expo-films-1901/',
#  'https://www.loc.gov/collections/lawrence-and-houseworth/',
#  'https://www.loc.gov/collections/legal-blawgs-web-archive/',
#  'https://www.loc.gov/collections/legislative-branch-web-archive/',
#  'https://www.loc.gov/collections/leonard-bernstein/',
#  'http://international.loc.gov/intldl/carrollhtml/lchome.html',
#  'https://www.loc.gov/collections/machen-family-papers/',
#  'https://www.loc.gov/collections/songs-of-america/',
#  'https://www.loc.gov/collections/concerts-from-the-library-of-congress/',
#  'https://www.loc.gov/collections/early-films-of-new-york-1898-to-1906/',
#  'https://www.loc.gov/collections/liljenquist-civil-war-photographs/',
#  'https://www.loc.gov/collections/lomax/',
#  'https://www.loc.gov/collections/look-magazine/',
#  'https://www.loc.gov/collections/louisiana-european-explorations-and-the-louisiana-purchase/',
#  'https://www.loc.gov/collections/manuscript-division-web-archive/',
#  'https://www.loc.gov/collections/manuscripts-in-st-catherines-monastery-mount-sinai/',
#  'https://www.loc.gov/collections/greek-and-armenian-patriarchates-of-jerusalem/',
#  'https://www.loc.gov/collections/national-parks-maps/',
#  'https://www.loc.gov/collections/maps-of-liberia-1830-to-1870/',
#  'https://www.loc.gov/collections/john-philip-sousa/',
#  'https://www.loc.gov/collections/margaret-bayard-smith-papers/',
#  'https://www.loc.gov/collections/martha-graham/',
#  'https://www.loc.gov/collections/martin-van-buren-papers/',
#  'https://www.loc.gov/collections/mary-ann-bickerdyke-papers/',
#  'https://www.loc.gov/collections/g-eric-and-edith-matson-photographs/',
#  'https://www.loc.gov/collections/military-battles-and-campaigns/',
#  'https://www.loc.gov/collections/millard-fillmore-papers/',
#  'http://memory.loc.gov/ammem/collections/suffrage/millerscrapbooks/',
#  'https://www.loc.gov/collections/moldenhauer-archives/',
#  'https://www.loc.gov/collections/montana-folklife-survey-1979/',
#  'https://www.loc.gov/collections/american-sheet-music-1820-to-1860/',
#  'https://www.loc.gov/collections/american-sheet-music-1870-to-1885/',
#  'https://www.loc.gov/collections/music-treasures-consortium/',
#  'https://www.loc.gov/collections/musical-instruments-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/nathan-w-daniels-diary-and-scrapbook/',
#  'https://www.loc.gov/collections/national-american-woman-suffrage-association/',
#  'https://www.loc.gov/collections/national-child-labor-committee/',
#  'http://www.loc.gov/jukebox/',
#  'https://www.loc.gov/collections/national-photo-company/',
#  'https://www.loc.gov/collections/new-york-journal/',
#  'https://www.loc.gov/collections/world-war-i-rotogravures/',
#  'https://www.loc.gov/collections/blues-gospel-and-the-fort-valley-music-festivals/',
#  'https://www.loc.gov/collections/occupational-folklife-project/',
#  'https://www.loc.gov/collections/omaha-indian-music/',
#  'https://www.loc.gov/collections/origins-of-american-animation/',
#  'https://www.loc.gov/collections/panoramic-maps/',
#  'https://www.loc.gov/collections/panoramic-photographs/',
#  'https://www.loc.gov/collections/papal-transition-2005-web-archive/',
#  'https://www.loc.gov/collections/patriotic-melodies/',
#  'https://www.loc.gov/collections/ph-filing-series-photographs/',
#  'https://www.loc.gov/collections/philip-henry-sheridan-papers/',
#  'https://www.loc.gov/collections/philippine-general-election-2010-web-archive/',
#  'https://www.loc.gov/collections/phillips-mathee-collection/',
#  'https://www.loc.gov/collections/photochrom-prints/',
#  'https://www.loc.gov/collections/pioneering-the-upper-midwest/',
#  'https://www.loc.gov/collections/polish-declarations/',
#  'https://www.loc.gov/collections/popular-graphic-arts/',
#  'https://www.loc.gov/collections/artists-posters/',
#  'https://www.loc.gov/collections/performing-arts-posters/',
#  'https://www.loc.gov/collections/spanish-civil-war-posters/',
#  'https://www.loc.gov/collections/world-war-i-posters/',
#  'https://www.loc.gov/collections/works-progress-administration-posters/',
#  'https://www.loc.gov/collections/yanker-posters/',
#  'http://memory.loc.gov/ammem/award98/nbhihtml/pshome.html',
#  'https://www.loc.gov/collections/pre-1700-musical-treasures/',
#  'https://www.loc.gov/collections/broadsides-and-other-printed-ephemera/',
#  'https://www.loc.gov/collections/prokudin-gorskii/',
#  'http://memory.loc.gov/ammem/coolhtml/coolhome.html',
#  'https://www.loc.gov/collections/public-policy-topics-web-archive/',
#  'https://www.loc.gov/collections/puerto-rico-books-and-pamphlets/',
#  'https://www.loc.gov/collections/quilts-and-quilt-making-in-america-from-1978-to-1996/',
#  'https://www.loc.gov/collections/ragtime/',
#  'https://www.loc.gov/collections/railroad-maps-1828-to-1900/',
#  'https://www.loc.gov/collections/rare-book-selections/',
#  'https://www.loc.gov/collections/rhode-island-folklife-project/',
#  'https://www.loc.gov/collections/rochambeau-maps/',
#  'https://www.loc.gov/collections/roger-reynolds/',
#  'https://www.loc.gov/collections/roman-totenberg-papers/',
#  'https://www.loc.gov/collections/totenberg-wilk/',
#  'https://www.loc.gov/collections/rosa-parks-papers/',
#  'https://www.loc.gov/collections/salmon-p-chase-papers/',
#  'https://www.loc.gov/collections/samuel-barber-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/samuel-morse-papers/',
#  'https://www.loc.gov/collections/samuel-j-gibson-papers/',
#  'https://www.loc.gov/collections/sanborn-maps/',
#  'https://www.loc.gov/collections/katherine-dunham/',
#  'https://www.loc.gov/collections/september-11-2001-web-archive/',
#  'https://www.loc.gov/collections/september-11th-2001-documentary-project/',
#  'https://www.loc.gov/collections/show-music-on-record/',
#  'https://www.loc.gov/collections/sigmund-freud-papers/',
#  'https://www.loc.gov/collections/sikkim-photos/',
#  'http://international.loc.gov/intldl/drakehtml/rbdkhome.html',
#  'https://www.loc.gov/collections/slaves-and-the-courts-from-1740-to-1860/',
#  'https://www.loc.gov/collections/small-press-expo-comic-and-comic-art-web-archive/',
#  'https://www.loc.gov/collections/south-central-georgia-folklife-project/',
#  'https://www.loc.gov/collections/john-and-ruby-lomax/',
#  'https://www.loc.gov/collections/spalding-base-ball-guides/',
#  'https://www.loc.gov/collections/spanish-american-war-in-motion-pictures/',
#  'https://www.loc.gov/collections/sports-byline/',
#  'https://www.loc.gov/collections/sri-lankan-presidential-and-general-elections-2010-web-archive/',
#  'https://www.loc.gov/collections/stars-and-stripes/',
#  'https://www.loc.gov/collections/stereograph-cards/',
#  'https://www.loc.gov/collections/folklife-and-landscape-in-southern-west-virginia/',
#  'https://www.loc.gov/collections/thai-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/theodore-roosevelt-films/',
#  'https://www.loc.gov/collections/harned-whitman-collection/',
#  'https://www.loc.gov/collections/thomas-jefferson-papers/',
#  'https://www.loc.gov/collections/tibetan-oral-history-project/',
#  'https://www.loc.gov/collections/timor-leste-2010-2011-web-archive/',
#  'https://www.loc.gov/collections/tissandier/',
#  'https://www.loc.gov/collections/today-in-history/',
#  'http://lcweb2.loc.gov/diglib/ihas/html/afccards/afccards-home.html',
#  'https://www.loc.gov/collections/transit-of-venus-march/',
#  'https://www.loc.gov/collections/transportation-and-communication/',
#  'https://www.loc.gov/collections/united-states-code/',
#  'https://www.loc.gov/collections/ulysses-s-grant-papers/',
#  'https://www.loc.gov/collections/united-states-congressional-web-archive/',
#  'https://www.loc.gov/collections/united-states-elections-web-archive/',
#  'https://www.loc.gov/collections/van-vechten/',
#  'http://www.loc.gov/vets/',
#  'https://www.loc.gov/collections/vietnam-era-pow-mia-database/',
#  'https://www.loc.gov/collections/vietnamese-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/visual-image-web-archive/',
#  'http://memory.loc.gov/ammem/collections/voices/',
#  'https://www.loc.gov/collections/todd-and-sonkin-migrant-workers-from-1940-to-1941/',
#  'https://www.loc.gov/collections/walt-whitman-papers-mmc/',
#  'https://www.loc.gov/collections/feinberg-whitman/',
#  'https://www.loc.gov/collections/warren-harding-carrie-fulton-phillips-correspondence/',
#  'https://www.loc.gov/collections/diary-of-horatio-taft/',
#  'https://www.loc.gov/collections/web-cultures-web-archive/',
#  'https://www.loc.gov/collections/webcomics-web-archive/',
#  'https://www.loc.gov/collections/wilbur-and-orville-wright-papers/',
#  'https://www.loc.gov/collections/william-henry-harrison-papers/',
#  'https://www.loc.gov/collections/jazz-photography-of-william-p-gottlieb/',
#  'https://www.loc.gov/collections/william-speiden-journals/',
#  'https://www.loc.gov/collections/william-t-sherman-papers/',
#  'https://www.loc.gov/collections/winter-olympic-games-2002-web-archive/',
#  'https://www.loc.gov/collections/wm-oland-bourne-papers/',
#  'https://www.loc.gov/collections/women-of-protest/',
#  'https://www.loc.gov/collections/woody-guthrie-correspondence-from-1940-to-1950/',
#  'https://www.loc.gov/collections/working-in-paterson/',
#  'https://www.loc.gov/collections/world-war-i-sheet-music/',
#  'https://www.loc.gov/collections/world-war-ii-maps-military-situation-maps-from-1944-to-1945/',
#  'https://www.loc.gov/collections/worlds-transportation-commission/',
#  'https://www.loc.gov/collections/wright-brothers-negatives/',
#  'https://www.loc.gov/collections/yiddish-american-popular-sheet-music/',
#  'https://www.loc.gov/collections/zachary-taylor-papers/',
#  'https://www.loc.gov/collections/zora-neale-hurston-plays/']

# %% [markdown]
# Wait, not all the collections URLs look the same! That's because (I think) not all of the collections are available via the loc.gov JSON API.  We need to limit our selection of collections to those that are actually available via the API. Collections with URLs beginning with the ones below are not available via the API:
# * memory.loc.gov
# * international.loc.gov
# * lcweb2.loc.gov
# * chroniclingamerica.loc.gov (Chronicling America has its own API, which is the best place to go for its data.)
#
# Also, collections that lack "collections" in their path are not queryable.
# * www.loc.gov/vets
# * www.loc.gov/jukebox

# %% [markdown]
# So let's only look at collections that have URLs that work for further API queries.

# %%
def get_usable_collections(list_of_collections):
    usable_collections = []
    for collection in list_of_collections:
        if "www.loc.gov/collections/" in collection:
            usable_collections.append(collection)
    return usable_collections
            
usable_collections = get_usable_collections(list_of_collections)
usable_collections
# Out:
# ['https://www.loc.gov/collections/aaron-copland/',
#  'https://www.loc.gov/collections/abdul-hamid-ii/',
#  'https://www.loc.gov/collections/abraham-lincoln-papers/',
#  'https://www.loc.gov/collections/afghanistan-web-archive/',
#  'https://www.loc.gov/collections/african-american-photographs-1900-paris-exposition/',
#  'https://www.loc.gov/collections/african-american-band-music/',
#  'https://www.loc.gov/collections/alan-lomax-manuscripts/',
#  'https://www.loc.gov/collections/alan-lomax-in-michigan/',
#  'https://www.loc.gov/collections/albert-schatz/',
#  'https://www.loc.gov/collections/alexander-graham-bell-papers/',
#  'https://www.loc.gov/collections/alexander-hamilton-papers/',
#  'https://www.loc.gov/collections/alexander-hamilton-stephens-papers/',
#  'https://www.loc.gov/collections/alfred-whital-stern-lincolniana/',
#  'https://www.loc.gov/collections/amazing-grace/',
#  'https://www.loc.gov/collections/america-at-work-and-leisure-1894-to-1915/',
#  'https://www.loc.gov/collections/nineteenth-century-song-sheets/',
#  'https://www.loc.gov/collections/dance-instruction-manuals-from-1490-to-1920/',
#  'https://www.loc.gov/collections/american-choral-music/',
#  'https://www.loc.gov/collections/american-colony-in-jerusalem/',
#  'https://www.loc.gov/collections/american-english-dialect-recordings-from-the-center-for-applied-linguistics/',
#  'https://www.loc.gov/collections/world-war-i-and-1920-election-recordings/',
#  'https://www.loc.gov/collections/federal-writers-project/',
#  'https://www.loc.gov/collections/travels-in-america-1750-to-1920/',
#  'https://www.loc.gov/collections/american-revolutionary-war-maps/',
#  'https://www.loc.gov/collections/andrew-jackson-papers/',
#  'https://www.loc.gov/collections/anna-maria-brodeau-thornton-papers/',
#  'https://www.loc.gov/collections/ansel-adams-manzanar/',
#  'https://www.loc.gov/collections/architecture-design-and-engineering-drawings/',
#  'https://www.loc.gov/collections/archive-of-hispanic-literature-on-tape/',
#  'https://www.loc.gov/collections/archive-of-recorded-poetry-and-literature/',
#  'https://www.loc.gov/collections/bain/',
#  'https://www.loc.gov/collections/ballets-russes-de-serge-diaghilev/',
#  'https://www.loc.gov/collections/civil-war-band-music/',
#  'https://www.loc.gov/collections/baseball-cards/',
#  'https://www.loc.gov/collections/baseball-sheet-music/',
#  'https://www.loc.gov/collections/san-francisco-earthquake-and-fire-1897-to-1916/',
#  'https://www.loc.gov/collections/slave-narratives-from-the-federal-writers-project-1936-to-1938/',
#  'https://www.loc.gov/collections/brady-handy/',
#  'https://www.loc.gov/collections/brazil-cordel-literature-web-archive/',
#  'https://www.loc.gov/collections/brazilian-presidential-election-2010-web-archive/',
#  'https://www.loc.gov/collections/bronislava-nijinska/',
#  'https://www.loc.gov/collections/brumfield/',
#  'https://www.loc.gov/collections/ranching-culture-in-northern-nevada-from-1945-to-1982/',
#  'https://www.loc.gov/collections/burma-myanmar-general-election-2010-web-archive/',
#  'https://www.loc.gov/collections/jackie-robinson-baseball/',
#  'https://www.loc.gov/collections/cabinet-of-american-illustration/',
#  'https://www.loc.gov/collections/california-first-person-narratives/',
#  'https://www.loc.gov/collections/sidney-robertson-cowell-northern-california-folk-music/',
#  'https://www.loc.gov/collections/cambini-collection/',
#  'https://www.loc.gov/collections/washington-and-chesapeake-bay-narratives/',
#  'https://www.loc.gov/collections/captain-pearl-r-nye-life-on-the-erie-and-ohio-canal/',
#  'https://www.loc.gov/collections/carnegie-hall-conversations-with-composers/',
#  'https://www.loc.gov/collections/carnegie-survey-architecture-of-the-south/',
#  'https://www.loc.gov/collections/carpenter/',
#  'https://www.loc.gov/collections/cartoon-drawings/',
#  'https://www.loc.gov/collections/herblock-cartoon-drawings/',
#  'https://www.loc.gov/collections/cartoon-drawings-swann/',
#  'https://www.loc.gov/collections/american-cartoon-prints/',
#  'https://www.loc.gov/collections/british-cartoon-prints/',
#  'https://www.loc.gov/collections/case-books/',
#  'https://www.loc.gov/collections/charles-reed/',
#  'https://www.loc.gov/collections/chicago-ethnic-arts-project/',
#  'https://www.loc.gov/collections/cities-and-towns/',
#  'https://www.loc.gov/collections/civil-rights-history-project/',
#  'https://www.loc.gov/collections/civil-war/',
#  'https://www.loc.gov/collections/civil-war-glass-negatives/',
#  'https://www.loc.gov/collections/civil-war-maps/',
#  'https://www.loc.gov/collections/civil-war-sheet-music/',
#  'https://www.loc.gov/collections/tilton-c-reynolds-papers/',
#  'https://www.loc.gov/collections/clara-barton-papers/',
#  'https://www.loc.gov/collections/college-womens-association-of-japan-print-show/',
#  'https://www.loc.gov/collections/confederate-states-of-america-records/',
#  'https://www.loc.gov/collections/coptic-orthodox-liturgical-chant/',
#  'https://www.loc.gov/collections/country-studies/',
#  'https://www.loc.gov/collections/crisis-in-darfur-2006-web-archive/',
#  'https://www.loc.gov/collections/edward-s-curtis/',
#  'https://www.loc.gov/collections/daguerreotypes/',
#  'https://www.loc.gov/collections/danny-kaye-and-sylvia-fine/',
#  'https://www.loc.gov/collections/dayton-c-miller-collection/',
#  'https://www.loc.gov/collections/detroit-publishing-company/',
#  'https://www.loc.gov/collections/discovery-and-exploration/',
#  'https://www.loc.gov/collections/continental-congress-and-constitutional-convention-from-1774-to-1789/',
#  'https://www.loc.gov/collections/dolly-parton-and-the-roots-of-country-music/',
#  'https://www.loc.gov/collections/documentary-drawings/',
#  'https://www.loc.gov/collections/master-drawings/',
#  'https://www.loc.gov/collections/early-american-sheet-music/',
#  'https://www.loc.gov/collections/edwin-mcmasters-stanton-papers/',
#  'https://www.loc.gov/collections/egypt-2008-web-archive/',
#  'https://www.loc.gov/collections/elliott-carter/',
#  'https://www.loc.gov/collections/emile-berliner/',
#  'https://www.loc.gov/collections/ernest-bloch/',
#  'https://www.loc.gov/collections/fsa-owi-black-and-white-negatives/',
#  'https://www.loc.gov/collections/fsa-owi-color-photographs/',
#  'https://www.loc.gov/collections/federal-courts-web-archive/',
#  'https://www.loc.gov/collections/federal-register/',
#  'https://www.loc.gov/collections/felix-mendelssohn/',
#  'https://www.loc.gov/collections/fenton-crimean-war-photographs/',
#  'https://www.loc.gov/collections/henry-reed-fiddle-tunes/',
#  'https://www.loc.gov/collections/finding-our-place-in-the-cosmos-with-carl-sagan/',
#  'https://www.loc.gov/collections/fine-prints/',
#  'https://www.loc.gov/collections/japanese-fine-prints-pre-1915/',
#  'https://www.loc.gov/collections/florida-folklife-from-the-works-progress-administration/',
#  'https://www.loc.gov/collections/franklin-pierce-papers/',
#  'https://www.loc.gov/collections/franz-liszt-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/frederick-douglass-papers/',
#  'https://www.loc.gov/collections/freedoms-fortress/',
#  'https://www.loc.gov/collections/foreign-affairs-oral-history/',
#  'https://www.loc.gov/collections/general-maps/',
#  'https://www.loc.gov/collections/genthe/',
#  'https://www.loc.gov/collections/george-s-patton-diaries/',
#  'https://www.loc.gov/collections/george-washington-papers/',
#  'https://www.loc.gov/collections/gerry-mulligan/',
#  'https://www.loc.gov/collections/gladstone-african-american-photographs/',
#  'https://www.loc.gov/collections/goldstein-foundation-prints-and-drawings/',
#  'https://www.loc.gov/collections/gottscho-schleisner/',
#  'https://www.loc.gov/collections/grabill/',
#  'https://www.loc.gov/collections/great-conversations-in-music/',
#  'https://www.loc.gov/collections/groups-of-images/',
#  'https://www.loc.gov/collections/guide-records/',
#  'https://www.loc.gov/collections/harris-ewing/',
#  'https://www.loc.gov/collections/hidden-treasures-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/carol-m-highsmith/',
#  'https://www.loc.gov/collections/hispano-music-and-culture-from-the-northern-rio-grande/',
#  'https://www.loc.gov/collections/historic-american-buildings-landscapes-and-engineering-records/',
#  'https://www.loc.gov/collections/historic-sheet-music/',
#  'https://www.loc.gov/collections/music-of-nineteenth-century-ohio/',
#  'https://www.loc.gov/collections/horydczak/',
#  'https://www.loc.gov/collections/hotchkiss-maps/',
#  'https://www.loc.gov/collections/ilka-kolsky-artwork/',
#  'https://www.loc.gov/collections/indian-general-election-2009-web-archive/',
#  'https://www.loc.gov/collections/indonesian-general-election-2009-web-archive/',
#  'https://www.loc.gov/collections/films-of-westinghouse-works-1904/',
#  'https://www.loc.gov/collections/international-tribunals-web-archive/',
#  'https://www.loc.gov/collections/edison-company-motion-pictures-and-sound-recordings/',
#  'https://www.loc.gov/collections/iraq-war-2003-web-archive/',
#  'https://www.loc.gov/collections/irving-fine/',
#  'https://www.loc.gov/collections/sheet-music-from-stage-and-screen/',
#  'https://www.loc.gov/collections/james-k-polk-papers/',
#  'https://www.loc.gov/collections/james-madison-papers/',
#  'https://www.loc.gov/collections/james-monroe-papers/',
#  'https://www.loc.gov/collections/japanese-american-internment-camp-newspapers/',
#  'https://www.loc.gov/collections/jazz-on-screen-filmography/',
#  'https://www.loc.gov/collections/jedediah-hotchkiss-papers/',
#  'https://www.loc.gov/collections/joe-smith/',
#  'https://www.loc.gov/collections/john-pershing-papers/',
#  'https://www.loc.gov/collections/john-tyler-papers/',
#  'https://www.loc.gov/collections/frances-benjamin-johnston/',
#  'https://www.loc.gov/collections/korab/',
#  'https://www.loc.gov/collections/lamb-studio/',
#  'https://www.loc.gov/collections/laotian-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/lars-schmidt/',
#  'https://www.loc.gov/collections/mckinley-and-the-pan-american-expo-films-1901/',
#  'https://www.loc.gov/collections/lawrence-and-houseworth/',
#  'https://www.loc.gov/collections/legal-blawgs-web-archive/',
#  'https://www.loc.gov/collections/legislative-branch-web-archive/',
#  'https://www.loc.gov/collections/leonard-bernstein/',
#  'https://www.loc.gov/collections/machen-family-papers/',
#  'https://www.loc.gov/collections/songs-of-america/',
#  'https://www.loc.gov/collections/concerts-from-the-library-of-congress/',
#  'https://www.loc.gov/collections/early-films-of-new-york-1898-to-1906/',
#  'https://www.loc.gov/collections/liljenquist-civil-war-photographs/',
#  'https://www.loc.gov/collections/lomax/',
#  'https://www.loc.gov/collections/look-magazine/',
#  'https://www.loc.gov/collections/louisiana-european-explorations-and-the-louisiana-purchase/',
#  'https://www.loc.gov/collections/manuscript-division-web-archive/',
#  'https://www.loc.gov/collections/manuscripts-in-st-catherines-monastery-mount-sinai/',
#  'https://www.loc.gov/collections/greek-and-armenian-patriarchates-of-jerusalem/',
#  'https://www.loc.gov/collections/national-parks-maps/',
#  'https://www.loc.gov/collections/maps-of-liberia-1830-to-1870/',
#  'https://www.loc.gov/collections/john-philip-sousa/',
#  'https://www.loc.gov/collections/margaret-bayard-smith-papers/',
#  'https://www.loc.gov/collections/martha-graham/',
#  'https://www.loc.gov/collections/martin-van-buren-papers/',
#  'https://www.loc.gov/collections/mary-ann-bickerdyke-papers/',
#  'https://www.loc.gov/collections/g-eric-and-edith-matson-photographs/',
#  'https://www.loc.gov/collections/military-battles-and-campaigns/',
#  'https://www.loc.gov/collections/millard-fillmore-papers/',
#  'https://www.loc.gov/collections/moldenhauer-archives/',
#  'https://www.loc.gov/collections/montana-folklife-survey-1979/',
#  'https://www.loc.gov/collections/american-sheet-music-1820-to-1860/',
#  'https://www.loc.gov/collections/american-sheet-music-1870-to-1885/',
#  'https://www.loc.gov/collections/music-treasures-consortium/',
#  'https://www.loc.gov/collections/musical-instruments-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/nathan-w-daniels-diary-and-scrapbook/',
#  'https://www.loc.gov/collections/national-american-woman-suffrage-association/',
#  'https://www.loc.gov/collections/national-child-labor-committee/',
#  'https://www.loc.gov/collections/national-photo-company/',
#  'https://www.loc.gov/collections/new-york-journal/',
#  'https://www.loc.gov/collections/world-war-i-rotogravures/',
#  'https://www.loc.gov/collections/blues-gospel-and-the-fort-valley-music-festivals/',
#  'https://www.loc.gov/collections/occupational-folklife-project/',
#  'https://www.loc.gov/collections/omaha-indian-music/',
#  'https://www.loc.gov/collections/origins-of-american-animation/',
#  'https://www.loc.gov/collections/panoramic-maps/',
#  'https://www.loc.gov/collections/panoramic-photographs/',
#  'https://www.loc.gov/collections/papal-transition-2005-web-archive/',
#  'https://www.loc.gov/collections/patriotic-melodies/',
#  'https://www.loc.gov/collections/ph-filing-series-photographs/',
#  'https://www.loc.gov/collections/philip-henry-sheridan-papers/',
#  'https://www.loc.gov/collections/philippine-general-election-2010-web-archive/',
#  'https://www.loc.gov/collections/phillips-mathee-collection/',
#  'https://www.loc.gov/collections/photochrom-prints/',
#  'https://www.loc.gov/collections/pioneering-the-upper-midwest/',
#  'https://www.loc.gov/collections/polish-declarations/',
#  'https://www.loc.gov/collections/popular-graphic-arts/',
#  'https://www.loc.gov/collections/artists-posters/',
#  'https://www.loc.gov/collections/performing-arts-posters/',
#  'https://www.loc.gov/collections/spanish-civil-war-posters/',
#  'https://www.loc.gov/collections/world-war-i-posters/',
#  'https://www.loc.gov/collections/works-progress-administration-posters/',
#  'https://www.loc.gov/collections/yanker-posters/',
#  'https://www.loc.gov/collections/pre-1700-musical-treasures/',
#  'https://www.loc.gov/collections/broadsides-and-other-printed-ephemera/',
#  'https://www.loc.gov/collections/prokudin-gorskii/',
#  'https://www.loc.gov/collections/public-policy-topics-web-archive/',
#  'https://www.loc.gov/collections/puerto-rico-books-and-pamphlets/',
#  'https://www.loc.gov/collections/quilts-and-quilt-making-in-america-from-1978-to-1996/',
#  'https://www.loc.gov/collections/ragtime/',
#  'https://www.loc.gov/collections/railroad-maps-1828-to-1900/',
#  'https://www.loc.gov/collections/rare-book-selections/',
#  'https://www.loc.gov/collections/rhode-island-folklife-project/',
#  'https://www.loc.gov/collections/rochambeau-maps/',
#  'https://www.loc.gov/collections/roger-reynolds/',
#  'https://www.loc.gov/collections/roman-totenberg-papers/',
#  'https://www.loc.gov/collections/totenberg-wilk/',
#  'https://www.loc.gov/collections/rosa-parks-papers/',
#  'https://www.loc.gov/collections/salmon-p-chase-papers/',
#  'https://www.loc.gov/collections/samuel-barber-at-the-library-of-congress/',
#  'https://www.loc.gov/collections/samuel-morse-papers/',
#  'https://www.loc.gov/collections/samuel-j-gibson-papers/',
#  'https://www.loc.gov/collections/sanborn-maps/',
#  'https://www.loc.gov/collections/katherine-dunham/',
#  'https://www.loc.gov/collections/september-11-2001-web-archive/',
#  'https://www.loc.gov/collections/september-11th-2001-documentary-project/',
#  'https://www.loc.gov/collections/show-music-on-record/',
#  'https://www.loc.gov/collections/sigmund-freud-papers/',
#  'https://www.loc.gov/collections/sikkim-photos/',
#  'https://www.loc.gov/collections/slaves-and-the-courts-from-1740-to-1860/',
#  'https://www.loc.gov/collections/small-press-expo-comic-and-comic-art-web-archive/',
#  'https://www.loc.gov/collections/south-central-georgia-folklife-project/',
#  'https://www.loc.gov/collections/john-and-ruby-lomax/',
#  'https://www.loc.gov/collections/spalding-base-ball-guides/',
#  'https://www.loc.gov/collections/spanish-american-war-in-motion-pictures/',
#  'https://www.loc.gov/collections/sports-byline/',
#  'https://www.loc.gov/collections/sri-lankan-presidential-and-general-elections-2010-web-archive/',
#  'https://www.loc.gov/collections/stars-and-stripes/',
#  'https://www.loc.gov/collections/stereograph-cards/',
#  'https://www.loc.gov/collections/folklife-and-landscape-in-southern-west-virginia/',
#  'https://www.loc.gov/collections/thai-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/theodore-roosevelt-films/',
#  'https://www.loc.gov/collections/harned-whitman-collection/',
#  'https://www.loc.gov/collections/thomas-jefferson-papers/',
#  'https://www.loc.gov/collections/tibetan-oral-history-project/',
#  'https://www.loc.gov/collections/timor-leste-2010-2011-web-archive/',
#  'https://www.loc.gov/collections/tissandier/',
#  'https://www.loc.gov/collections/today-in-history/',
#  'https://www.loc.gov/collections/transit-of-venus-march/',
#  'https://www.loc.gov/collections/transportation-and-communication/',
#  'https://www.loc.gov/collections/united-states-code/',
#  'https://www.loc.gov/collections/ulysses-s-grant-papers/',
#  'https://www.loc.gov/collections/united-states-congressional-web-archive/',
#  'https://www.loc.gov/collections/united-states-elections-web-archive/',
#  'https://www.loc.gov/collections/van-vechten/',
#  'https://www.loc.gov/collections/vietnam-era-pow-mia-database/',
#  'https://www.loc.gov/collections/vietnamese-general-election-2011-web-archive/',
#  'https://www.loc.gov/collections/visual-image-web-archive/',
#  'https://www.loc.gov/collections/todd-and-sonkin-migrant-workers-from-1940-to-1941/',
#  'https://www.loc.gov/collections/walt-whitman-papers-mmc/',
#  'https://www.loc.gov/collections/feinberg-whitman/',
#  'https://www.loc.gov/collections/warren-harding-carrie-fulton-phillips-correspondence/',
#  'https://www.loc.gov/collections/diary-of-horatio-taft/',
#  'https://www.loc.gov/collections/web-cultures-web-archive/',
#  'https://www.loc.gov/collections/webcomics-web-archive/',
#  'https://www.loc.gov/collections/wilbur-and-orville-wright-papers/',
#  'https://www.loc.gov/collections/william-henry-harrison-papers/',
#  'https://www.loc.gov/collections/jazz-photography-of-william-p-gottlieb/',
#  'https://www.loc.gov/collections/william-speiden-journals/',
#  'https://www.loc.gov/collections/william-t-sherman-papers/',
#  'https://www.loc.gov/collections/winter-olympic-games-2002-web-archive/',
#  'https://www.loc.gov/collections/wm-oland-bourne-papers/',
#  'https://www.loc.gov/collections/women-of-protest/',
#  'https://www.loc.gov/collections/woody-guthrie-correspondence-from-1940-to-1950/',
#  'https://www.loc.gov/collections/working-in-paterson/',
#  'https://www.loc.gov/collections/world-war-i-sheet-music/',
#  'https://www.loc.gov/collections/world-war-ii-maps-military-situation-maps-from-1944-to-1945/',
#  'https://www.loc.gov/collections/worlds-transportation-commission/',
#  'https://www.loc.gov/collections/wright-brothers-negatives/',
#  'https://www.loc.gov/collections/yiddish-american-popular-sheet-music/',
#  'https://www.loc.gov/collections/zachary-taylor-papers/',
#  'https://www.loc.gov/collections/zora-neale-hurston-plays/']

# %% [markdown]
# How many collections are now in the list?

# %%
len(usable_collections)
# Out:
# 290

# %% [markdown]
# Not sure if we'll need this but here's a new function that will get just the "slug" (the hyphenated name of the collection in the URL) for those collections that can be queried via the URL.

# %%
def get_collection_slugs(url, coll_list=[]): 
    call = requests.get(url)
    data = call.json()
    results = data["results"]   
    for result in results:
        coll = result.get("items")
        if "www.loc.gov/collections/" in coll:
            slug = coll.split("/")[-2] # grab the collection slug at the end of the URL, before the trailing slash
            coll_list.append(slug)
    if data["pagination"]["next"] is not None: #make sure we haven't hit the end of the pages
        next_url = data["pagination"]["next"]
        get_collections(next_url, coll_list)
    
    return coll_list

url = "https://www.loc.gov/collections/?fo=json"
collection_slugs = get_collection_slugs(url)

collection_slugs
# Out:
# ['aaron-copland',
#  'abdul-hamid-ii',
#  'abraham-lincoln-papers',
#  'afghanistan-web-archive',
#  'african-american-photographs-1900-paris-exposition',
#  'african-american-band-music',
#  'alan-lomax-manuscripts',
#  'alan-lomax-in-michigan',
#  'albert-schatz',
#  'alexander-graham-bell-papers',
#  'alexander-hamilton-papers',
#  'alexander-hamilton-stephens-papers',
#  'alfred-whital-stern-lincolniana',
#  'amazing-grace',
#  'america-at-work-and-leisure-1894-to-1915',
#  'nineteenth-century-song-sheets',
#  'dance-instruction-manuals-from-1490-to-1920',
#  'american-choral-music',
#  'american-colony-in-jerusalem',
#  'american-english-dialect-recordings-from-the-center-for-applied-linguistics',
#  'world-war-i-and-1920-election-recordings',
#  'federal-writers-project',
#  'travels-in-america-1750-to-1920',
#  'american-revolutionary-war-maps',
#  'andrew-jackson-papers',
#  'anna-maria-brodeau-thornton-papers',
#  'ansel-adams-manzanar',
#  'architecture-design-and-engineering-drawings',
#  'archive-of-hispanic-literature-on-tape',
#  'archive-of-recorded-poetry-and-literature',
#  'bain',
#  'ballets-russes-de-serge-diaghilev',
#  'civil-war-band-music',
#  'baseball-cards',
#  'baseball-sheet-music',
#  'san-francisco-earthquake-and-fire-1897-to-1916',
#  'slave-narratives-from-the-federal-writers-project-1936-to-1938',
#  'brady-handy',
#  'brazil-cordel-literature-web-archive',
#  'brazilian-presidential-election-2010-web-archive',
#  'bronislava-nijinska',
#  'brumfield',
#  'ranching-culture-in-northern-nevada-from-1945-to-1982',
#  'burma-myanmar-general-election-2010-web-archive',
#  'jackie-robinson-baseball',
#  'cabinet-of-american-illustration',
#  'california-first-person-narratives',
#  'sidney-robertson-cowell-northern-california-folk-music',
#  'cambini-collection',
#  'washington-and-chesapeake-bay-narratives',
#  'captain-pearl-r-nye-life-on-the-erie-and-ohio-canal',
#  'carnegie-hall-conversations-with-composers',
#  'carnegie-survey-architecture-of-the-south',
#  'carpenter',
#  'cartoon-drawings',
#  'herblock-cartoon-drawings',
#  'cartoon-drawings-swann',
#  'american-cartoon-prints',
#  'british-cartoon-prints',
#  'case-books',
#  'charles-reed',
#  'chicago-ethnic-arts-project',
#  'cities-and-towns',
#  'civil-rights-history-project',
#  'civil-war',
#  'civil-war-glass-negatives',
#  'civil-war-maps',
#  'civil-war-sheet-music',
#  'tilton-c-reynolds-papers',
#  'clara-barton-papers',
#  'college-womens-association-of-japan-print-show',
#  'confederate-states-of-america-records',
#  'coptic-orthodox-liturgical-chant',
#  'country-studies',
#  'crisis-in-darfur-2006-web-archive',
#  'edward-s-curtis',
#  'daguerreotypes',
#  'danny-kaye-and-sylvia-fine',
#  'dayton-c-miller-collection',
#  'detroit-publishing-company',
#  'discovery-and-exploration',
#  'continental-congress-and-constitutional-convention-from-1774-to-1789',
#  'dolly-parton-and-the-roots-of-country-music',
#  'documentary-drawings',
#  'master-drawings',
#  'early-american-sheet-music',
#  'edwin-mcmasters-stanton-papers',
#  'egypt-2008-web-archive',
#  'elliott-carter',
#  'emile-berliner',
#  'ernest-bloch',
#  'fsa-owi-black-and-white-negatives',
#  'fsa-owi-color-photographs',
#  'federal-courts-web-archive',
#  'federal-register',
#  'felix-mendelssohn',
#  'fenton-crimean-war-photographs',
#  'henry-reed-fiddle-tunes',
#  'finding-our-place-in-the-cosmos-with-carl-sagan',
#  'fine-prints',
#  'japanese-fine-prints-pre-1915',
#  'florida-folklife-from-the-works-progress-administration',
#  'franklin-pierce-papers',
#  'franz-liszt-at-the-library-of-congress',
#  'frederick-douglass-papers',
#  'freedoms-fortress',
#  'foreign-affairs-oral-history',
#  'general-maps',
#  'genthe',
#  'george-s-patton-diaries',
#  'george-washington-papers',
#  'gerry-mulligan',
#  'gladstone-african-american-photographs',
#  'goldstein-foundation-prints-and-drawings',
#  'gottscho-schleisner',
#  'grabill',
#  'great-conversations-in-music',
#  'groups-of-images',
#  'guide-records',
#  'harris-ewing',
#  'hidden-treasures-at-the-library-of-congress',
#  'carol-m-highsmith',
#  'hispano-music-and-culture-from-the-northern-rio-grande',
#  'historic-american-buildings-landscapes-and-engineering-records',
#  'historic-sheet-music',
#  'music-of-nineteenth-century-ohio',
#  'horydczak',
#  'hotchkiss-maps',
#  'ilka-kolsky-artwork',
#  'indian-general-election-2009-web-archive',
#  'indonesian-general-election-2009-web-archive',
#  'films-of-westinghouse-works-1904',
#  'international-tribunals-web-archive',
#  'edison-company-motion-pictures-and-sound-recordings',
#  'iraq-war-2003-web-archive',
#  'irving-fine',
#  'sheet-music-from-stage-and-screen',
#  'james-k-polk-papers',
#  'james-madison-papers',
#  'james-monroe-papers',
#  'japanese-american-internment-camp-newspapers',
#  'jazz-on-screen-filmography',
#  'jedediah-hotchkiss-papers',
#  'joe-smith',
#  'john-pershing-papers',
#  'john-tyler-papers',
#  'frances-benjamin-johnston',
#  'korab',
#  'lamb-studio',
#  'laotian-general-election-2011-web-archive',
#  'lars-schmidt',
#  'mckinley-and-the-pan-american-expo-films-1901',
#  'lawrence-and-houseworth',
#  'legal-blawgs-web-archive',
#  'legislative-branch-web-archive',
#  'leonard-bernstein',
#  'machen-family-papers',
#  'songs-of-america',
#  'concerts-from-the-library-of-congress',
#  'early-films-of-new-york-1898-to-1906',
#  'liljenquist-civil-war-photographs',
#  'lomax',
#  'look-magazine',
#  'louisiana-european-explorations-and-the-louisiana-purchase',
#  'manuscript-division-web-archive',
#  'manuscripts-in-st-catherines-monastery-mount-sinai',
#  'greek-and-armenian-patriarchates-of-jerusalem',
#  'national-parks-maps',
#  'maps-of-liberia-1830-to-1870',
#  'john-philip-sousa',
#  'margaret-bayard-smith-papers',
#  'martha-graham',
#  'martin-van-buren-papers',
#  'mary-ann-bickerdyke-papers',
#  'g-eric-and-edith-matson-photographs',
#  'military-battles-and-campaigns',
#  'millard-fillmore-papers',
#  'moldenhauer-archives',
#  'montana-folklife-survey-1979',
#  'american-sheet-music-1820-to-1860',
#  'american-sheet-music-1870-to-1885',
#  'music-treasures-consortium',
#  'musical-instruments-at-the-library-of-congress',
#  'nathan-w-daniels-diary-and-scrapbook',
#  'national-american-woman-suffrage-association',
#  'national-child-labor-committee',
#  'national-photo-company',
#  'new-york-journal',
#  'world-war-i-rotogravures',
#  'blues-gospel-and-the-fort-valley-music-festivals',
#  'occupational-folklife-project',
#  'omaha-indian-music',
#  'origins-of-american-animation',
#  'panoramic-maps',
#  'panoramic-photographs',
#  'papal-transition-2005-web-archive',
#  'patriotic-melodies',
#  'ph-filing-series-photographs',
#  'philip-henry-sheridan-papers',
#  'philippine-general-election-2010-web-archive',
#  'phillips-mathee-collection',
#  'photochrom-prints',
#  'pioneering-the-upper-midwest',
#  'polish-declarations',
#  'popular-graphic-arts',
#  'artists-posters',
#  'performing-arts-posters',
#  'spanish-civil-war-posters',
#  'world-war-i-posters',
#  'works-progress-administration-posters',
#  'yanker-posters',
#  'pre-1700-musical-treasures',
#  'broadsides-and-other-printed-ephemera',
#  'prokudin-gorskii',
#  'public-policy-topics-web-archive',
#  'puerto-rico-books-and-pamphlets',
#  'quilts-and-quilt-making-in-america-from-1978-to-1996',
#  'ragtime',
#  'railroad-maps-1828-to-1900',
#  'rare-book-selections',
#  'rhode-island-folklife-project',
#  'rochambeau-maps',
#  'roger-reynolds',
#  'roman-totenberg-papers',
#  'totenberg-wilk',
#  'rosa-parks-papers',
#  'salmon-p-chase-papers',
#  'samuel-barber-at-the-library-of-congress',
#  'samuel-morse-papers',
#  'samuel-j-gibson-papers',
#  'sanborn-maps',
#  'katherine-dunham',
#  'september-11-2001-web-archive',
#  'september-11th-2001-documentary-project',
#  'show-music-on-record',
#  'sigmund-freud-papers',
#  'sikkim-photos',
#  'slaves-and-the-courts-from-1740-to-1860',
#  'small-press-expo-comic-and-comic-art-web-archive',
#  'south-central-georgia-folklife-project',
#  'john-and-ruby-lomax',
#  'spalding-base-ball-guides',
#  'spanish-american-war-in-motion-pictures',
#  'sports-byline',
#  'sri-lankan-presidential-and-general-elections-2010-web-archive',
#  'stars-and-stripes',
#  'stereograph-cards',
#  'folklife-and-landscape-in-southern-west-virginia',
#  'thai-general-election-2011-web-archive',
#  'theodore-roosevelt-films',
#  'harned-whitman-collection',
#  'thomas-jefferson-papers',
#  'tibetan-oral-history-project',
#  'timor-leste-2010-2011-web-archive',
#  'tissandier',
#  'today-in-history',
#  'transit-of-venus-march',
#  'transportation-and-communication',
#  'united-states-code',
#  'ulysses-s-grant-papers',
#  'united-states-congressional-web-archive',
#  'united-states-elections-web-archive',
#  'van-vechten',
#  'vietnam-era-pow-mia-database',
#  'vietnamese-general-election-2011-web-archive',
#  'visual-image-web-archive',
#  'todd-and-sonkin-migrant-workers-from-1940-to-1941',
#  'walt-whitman-papers-mmc',
#  'feinberg-whitman',
#  'warren-harding-carrie-fulton-phillips-correspondence',
#  'diary-of-horatio-taft',
#  'web-cultures-web-archive',
#  'webcomics-web-archive',
#  'wilbur-and-orville-wright-papers',
#  'william-henry-harrison-papers',
#  'jazz-photography-of-william-p-gottlieb',
#  'william-speiden-journals',
#  'william-t-sherman-papers',
#  'winter-olympic-games-2002-web-archive',
#  'wm-oland-bourne-papers',
#  'women-of-protest',
#  'woody-guthrie-correspondence-from-1940-to-1950',
#  'working-in-paterson',
#  'world-war-i-sheet-music',
#  'world-war-ii-maps-military-situation-maps-from-1944-to-1945',
#  'worlds-transportation-commission',
#  'wright-brothers-negatives',
#  'yiddish-american-popular-sheet-music',
#  'zachary-taylor-papers',
#  'zora-neale-hurston-plays']

# %% [markdown]
# ## Back to exploring fields with ids
#
# Let's get back to my original goal of understanding whether "id" or "item_id" is reliable for making item queries for specific collections. I'll check a record from each collection to see which ID fields are in use in that collection.

# %%
def check_id_fields(collections):
    collection_ids = []
    for collection in collections: 
        url = collection + "?fo=json"
        call = requests.get(url)
        data = call.json()
        # the first result is always(?) the collection-level record, so look at the second record. 
        item = data["results"][1]
        # get the slug for saving for analysis
        slug = collection.split("/")[-2]
        # create a dictionary for each collection and its id fields
        entry = {"collection": slug, "item_id": item.get("item_id"), "id": item.get("id")}
        collection_ids.append(entry)
   
    return collection_ids

id_fields_per_coll = check_id_fields(usable_collections)

# %%
id_fields_per_coll
# Out:
# [{'collection': 'aaron-copland',
#   'id': 'http://www.loc.gov/item/copland.sket0019/',
#   'item_id': 'copland.sket0019/'},
#  {'collection': 'abdul-hamid-ii',
#   'id': 'http://www.loc.gov/item/2003673365/',
#   'item_id': None},
#  {'collection': 'abraham-lincoln-papers',
#   'id': 'http://www.loc.gov/collections/abraham-lincoln-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'afghanistan-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0003131/',
#   'item_id': None},
#  {'collection': 'african-american-photographs-1900-paris-exposition',
#   'id': 'http://www.loc.gov/item/98504044/',
#   'item_id': None},
#  {'collection': 'african-american-band-music',
#   'id': 'http://www.loc.gov/item/ihas.100010758/',
#   'item_id': None},
#  {'collection': 'alan-lomax-manuscripts',
#   'id': 'http://www.loc.gov/item/afc2004004.ms010101/',
#   'item_id': 'afc2004004.ms010101/'},
#  {'collection': 'alan-lomax-in-michigan',
#   'id': 'http://www.loc.gov/item/afc1939007_afs02237b/',
#   'item_id': None},
#  {'collection': 'albert-schatz',
#   'id': 'http://www.loc.gov/item/2010656607/',
#   'item_id': '2010656607/'},
#  {'collection': 'alexander-graham-bell-papers',
#   'id': 'http://www.loc.gov/item/magbell.37500101/',
#   'item_id': 'magbell.37500101/'},
#  {'collection': 'alexander-hamilton-papers',
#   'id': 'http://www.loc.gov/collections/alexander-hamilton-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'alexander-hamilton-stephens-papers',
#   'id': 'http://www.loc.gov/collections/alexander-hamilton-stephens-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'alfred-whital-stern-lincolniana',
#   'id': 'http://www.loc.gov/item/2004573227/',
#   'item_id': '2004573227/'},
#  {'collection': 'amazing-grace',
#   'id': 'http://www.loc.gov/item/ihas.200049058/',
#   'item_id': None},
#  {'collection': 'america-at-work-and-leisure-1894-to-1915',
#   'id': 'http://www.loc.gov/item/00694290/',
#   'item_id': None},
#  {'collection': 'nineteenth-century-song-sheets',
#   'id': 'http://www.loc.gov/item/amss.cw101770/',
#   'item_id': None},
#  {'collection': 'dance-instruction-manuals-from-1490-to-1920',
#   'id': 'http://lccn.loc.gov/12012085',
#   'item_id': None},
#  {'collection': 'american-choral-music',
#   'id': 'http://www.loc.gov/item/2008560881/',
#   'item_id': '2008560881/'},
#  {'collection': 'american-colony-in-jerusalem',
#   'id': 'http://www.loc.gov/item/mamcol.002/',
#   'item_id': 'mamcol.002/'},
#  {'collection': 'american-english-dialect-recordings-from-the-center-for-applied-linguistics',
#   'id': 'http://www.loc.gov/item/afccal000004/',
#   'item_id': None},
#  {'collection': 'world-war-i-and-1920-election-recordings',
#   'id': 'http://www.loc.gov/item/00652537/',
#   'item_id': None},
#  {'collection': 'federal-writers-project',
#   'id': 'http://www.loc.gov/item/wpalh000002/',
#   'item_id': 'wpalh000002/'},
#  {'collection': 'travels-in-america-1750-to-1920',
#   'id': 'http://www.loc.gov/item/a33002771/',
#   'item_id': 'a33002771/'},
#  {'collection': 'american-revolutionary-war-maps',
#   'id': 'http://www.loc.gov/item/74175046/',
#   'item_id': '74175046/'},
#  {'collection': 'andrew-jackson-papers',
#   'id': 'http://www.loc.gov/item/maj025706/',
#   'item_id': 'maj025706/'},
#  {'collection': 'anna-maria-brodeau-thornton-papers',
#   'id': 'http://www.loc.gov/collections/anna-maria-brodeau-thornton-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'ansel-adams-manzanar',
#   'id': 'http://www.loc.gov/item/2002695950/',
#   'item_id': None},
#  {'collection': 'architecture-design-and-engineering-drawings',
#   'id': 'http://www.loc.gov/item/95858359/',
#   'item_id': None},
#  {'collection': 'archive-of-hispanic-literature-on-tape',
#   'id': 'http://www.loc.gov/item/2016686101/',
#   'item_id': None},
#  {'collection': 'archive-of-recorded-poetry-and-literature',
#   'id': 'http://www.loc.gov/item/91740870/',
#   'item_id': None},
#  {'collection': 'bain',
#   'id': 'http://www.loc.gov/item/91784351/',
#   'item_id': None},
#  {'collection': 'ballets-russes-de-serge-diaghilev',
#   'id': 'http://www.loc.gov/collections/ballets-russes-de-serge-diaghilev/about-this-collection/',
#   'item_id': None},
#  {'collection': 'civil-war-band-music',
#   'id': 'http://www.loc.gov/collections/civil-war-band-music/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'baseball-cards',
#   'id': 'http://www.loc.gov/item/2007678540/',
#   'item_id': None},
#  {'collection': 'baseball-sheet-music',
#   'id': 'http://www.loc.gov/item/ihas.200197875/',
#   'item_id': None},
#  {'collection': 'san-francisco-earthquake-and-fire-1897-to-1916',
#   'id': 'http://www.loc.gov/item/00694419/',
#   'item_id': None},
#  {'collection': 'slave-narratives-from-the-federal-writers-project-1936-to-1938',
#   'id': 'http://www.loc.gov/item/99615421/',
#   'item_id': None},
#  {'collection': 'brady-handy',
#   'id': 'http://www.loc.gov/item/brh2003003712/PP/',
#   'item_id': None},
#  {'collection': 'brazil-cordel-literature-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0006275/',
#   'item_id': None},
#  {'collection': 'brazilian-presidential-election-2010-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00097011/',
#   'item_id': None},
#  {'collection': 'bronislava-nijinska',
#   'id': 'http://www.loc.gov/collections/bronislava-nijinska/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'brumfield',
#   'id': 'http://www.loc.gov/item/bru2000000002/',
#   'item_id': None},
#  {'collection': 'ranching-culture-in-northern-nevada-from-1945-to-1982',
#   'id': 'http://www.loc.gov/collections/ranching-culture-in-northern-nevada-from-1945-to-1982/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'burma-myanmar-general-election-2010-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00096306/',
#   'item_id': None},
#  {'collection': 'jackie-robinson-baseball',
#   'id': 'http://www.loc.gov/item/89714223/',
#   'item_id': None},
#  {'collection': 'cabinet-of-american-illustration',
#   'id': 'http://www.loc.gov/item/2010714815/',
#   'item_id': None},
#  {'collection': 'california-first-person-narratives',
#   'id': 'http://www.loc.gov/item/21020428/',
#   'item_id': None},
#  {'collection': 'sidney-robertson-cowell-northern-california-folk-music',
#   'id': 'http://www.loc.gov/item/2017655315/',
#   'item_id': None},
#  {'collection': 'cambini-collection',
#   'id': 'http://www.loc.gov/collections/cambini-collection/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'washington-and-chesapeake-bay-narratives',
#   'id': 'http://www.loc.gov/item/2004695062/',
#   'item_id': '2004695062/'},
#  {'collection': 'captain-pearl-r-nye-life-on-the-erie-and-ohio-canal',
#   'id': 'http://www.loc.gov/item/afcnye000002/',
#   'item_id': None},
#  {'collection': 'carnegie-hall-conversations-with-composers',
#   'id': 'http://www.loc.gov/collections/carnegie-hall-conversations-with-composers/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'carnegie-survey-architecture-of-the-south',
#   'id': 'http://www.loc.gov/item/csas200800002/',
#   'item_id': None},
#  {'collection': 'carpenter',
#   'id': 'http://www.loc.gov/item/90712825/',
#   'item_id': None},
#  {'collection': 'cartoon-drawings',
#   'id': 'http://www.loc.gov/item/2016666100/',
#   'item_id': None},
#  {'collection': 'herblock-cartoon-drawings',
#   'id': 'http://www.loc.gov/item/2010635544/',
#   'item_id': None},
#  {'collection': 'cartoon-drawings-swann',
#   'id': 'http://www.loc.gov/collections/cartoon-drawings-swann/about-this-collection/',
#   'item_id': None},
#  {'collection': 'american-cartoon-prints',
#   'id': 'http://www.loc.gov/item/2008661724/',
#   'item_id': None},
#  {'collection': 'british-cartoon-prints',
#   'id': 'http://www.loc.gov/collections/british-cartoon-prints/about-this-collection/',
#   'item_id': None},
#  {'collection': 'case-books',
#   'id': 'http://www.loc.gov/item/17031662/',
#   'item_id': None},
#  {'collection': 'charles-reed',
#   'id': 'http://www.loc.gov/collections/charles-reed/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'chicago-ethnic-arts-project',
#   'id': 'http://www.loc.gov/item/afc1981004.002/',
#   'item_id': 'afc1981004.002/'},
#  {'collection': 'cities-and-towns',
#   'id': 'http://www.loc.gov/item/2008627031/',
#   'item_id': '2008627031/'},
#  {'collection': 'civil-rights-history-project',
#   'id': 'http://www.loc.gov/item/2015669102/',
#   'item_id': '2015669102/'},
#  {'collection': 'civil-war',
#   'id': 'http://www.loc.gov/item/2002719396/',
#   'item_id': None},
#  {'collection': 'civil-war-glass-negatives',
#   'id': 'http://www.loc.gov/item/2002719476/',
#   'item_id': None},
#  {'collection': 'civil-war-maps',
#   'id': 'http://www.loc.gov/item/03003452/',
#   'item_id': '03003452/'},
#  {'collection': 'civil-war-sheet-music',
#   'id': 'http://www.loc.gov/item/ihas.200001548/',
#   'item_id': 'ihas.200001548/'},
#  {'collection': 'tilton-c-reynolds-papers',
#   'id': 'http://www.loc.gov/item/mreynolds000073/',
#   'item_id': 'mreynolds000073/'},
#  {'collection': 'clara-barton-papers',
#   'id': 'http://www.loc.gov/collections/clara-barton-papers/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'college-womens-association-of-japan-print-show',
#   'id': 'http://www.loc.gov/item/2006688065/',
#   'item_id': None},
#  {'collection': 'confederate-states-of-america-records',
#   'id': 'http://www.loc.gov/item/mss16550038/',
#   'item_id': 'mss16550038/'},
#  {'collection': 'coptic-orthodox-liturgical-chant',
#   'id': 'http://www.loc.gov/item/31008705/',
#   'item_id': '31008705/'},
#  {'collection': 'country-studies',
#   'id': 'http://www.loc.gov/item/88600487/',
#   'item_id': '88600487/'},
#  {'collection': 'crisis-in-darfur-2006-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00087341/',
#   'item_id': None},
#  {'collection': 'edward-s-curtis',
#   'id': 'http://www.loc.gov/item/2003652796/',
#   'item_id': None},
#  {'collection': 'daguerreotypes',
#   'id': 'http://www.loc.gov/item/2004664011/',
#   'item_id': None},
#  {'collection': 'danny-kaye-and-sylvia-fine',
#   'id': 'http://www.loc.gov/item/ihas.200187493/',
#   'item_id': None},
#  {'collection': 'dayton-c-miller-collection',
#   'id': 'http://www.loc.gov/item/dcmphot.a0054/',
#   'item_id': None},
#  {'collection': 'detroit-publishing-company',
#   'id': 'http://www.loc.gov/item/det1994002142/PP/',
#   'item_id': None},
#  {'collection': 'discovery-and-exploration',
#   'id': 'http://www.loc.gov/item/2003627089/',
#   'item_id': None},
#  {'collection': 'continental-congress-and-constitutional-convention-from-1774-to-1789',
#   'id': 'http://www.loc.gov/item/90898139/',
#   'item_id': '90898139/'},
#  {'collection': 'dolly-parton-and-the-roots-of-country-music',
#   'id': 'http://www.loc.gov/item/ihas.200003689/',
#   'item_id': None},
#  {'collection': 'documentary-drawings',
#   'id': 'http://www.loc.gov/item/2010652217/',
#   'item_id': None},
#  {'collection': 'master-drawings',
#   'id': 'http://www.loc.gov/item/2007666938/',
#   'item_id': None},
#  {'collection': 'early-american-sheet-music',
#   'id': 'http://www.loc.gov/item/2015562605/',
#   'item_id': '2015562605/'},
#  {'collection': 'edwin-mcmasters-stanton-papers',
#   'id': 'http://www.loc.gov/item/mss41202028/',
#   'item_id': 'mss41202028/'},
#  {'collection': 'egypt-2008-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00090639/',
#   'item_id': None},
#  {'collection': 'elliott-carter',
#   'id': 'http://www.loc.gov/item/88753851/',
#   'item_id': '88753851/'},
#  {'collection': 'emile-berliner',
#   'id': 'http://www.loc.gov/item/00694632/',
#   'item_id': None},
#  {'collection': 'ernest-bloch',
#   'id': 'http://www.loc.gov/item/2009546920/',
#   'item_id': '2009546920/'},
#  {'collection': 'fsa-owi-black-and-white-negatives',
#   'id': 'http://www.loc.gov/item/fsa2008000026/PP/',
#   'item_id': None},
#  {'collection': 'fsa-owi-color-photographs',
#   'id': 'http://www.loc.gov/item/fsa1992000012/PP/',
#   'item_id': None},
#  {'collection': 'federal-courts-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0013790/',
#   'item_id': None},
#  {'collection': 'federal-register',
#   'id': 'http://www.loc.gov/item/fr001002/',
#   'item_id': None},
#  {'collection': 'felix-mendelssohn',
#   'id': 'http://www.loc.gov/item/2009537803/',
#   'item_id': None},
#  {'collection': 'fenton-crimean-war-photographs',
#   'id': 'http://www.loc.gov/item/2001696347/',
#   'item_id': None},
#  {'collection': 'henry-reed-fiddle-tunes',
#   'id': 'http://www.loc.gov/item/afcreed000080/',
#   'item_id': None},
#  {'collection': 'finding-our-place-in-the-cosmos-with-carl-sagan',
#   'id': 'http://www.loc.gov/item/cmns000044/',
#   'item_id': None},
#  {'collection': 'fine-prints',
#   'id': 'http://www.loc.gov/item/2015650881/',
#   'item_id': None},
#  {'collection': 'japanese-fine-prints-pre-1915',
#   'id': 'http://www.loc.gov/item/2002700349/',
#   'item_id': None},
#  {'collection': 'florida-folklife-from-the-works-progress-administration',
#   'id': 'http://www.loc.gov/item/flwpa000004/',
#   'item_id': None},
#  {'collection': 'franklin-pierce-papers',
#   'id': 'http://www.loc.gov/collections/franklin-pierce-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'franz-liszt-at-the-library-of-congress',
#   'id': 'http://www.loc.gov/item/87002914/',
#   'item_id': '87002914/'},
#  {'collection': 'frederick-douglass-papers',
#   'id': 'http://www.loc.gov/collections/frederick-douglass-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'freedoms-fortress',
#   'id': 'http://www.loc.gov/item/mff000165/',
#   'item_id': 'mff000165/'},
#  {'collection': 'foreign-affairs-oral-history',
#   'id': 'http://www.loc.gov/item/mfdipbib001470/',
#   'item_id': None},
#  {'collection': 'general-maps',
#   'id': 'http://www.loc.gov/item/09021043/',
#   'item_id': None},
#  {'collection': 'genthe',
#   'id': 'http://www.loc.gov/item/agc1996000203/PP/',
#   'item_id': None},
#  {'collection': 'george-s-patton-diaries',
#   'id': 'http://www.loc.gov/item/mss35634014/',
#   'item_id': 'mss35634014/'},
#  {'collection': 'george-washington-papers',
#   'id': 'http://www.loc.gov/collections/george-washington-papers/about-this-collection/',
#   'item_id': None},
#  {'collection': 'gerry-mulligan',
#   'id': 'http://www.loc.gov/item/ihas.100010327/',
#   'item_id': None},
#  {'collection': 'gladstone-african-american-photographs',
#   'id': 'http://www.loc.gov/item/2002719396/',
#   'item_id': None},
#  {'collection': 'goldstein-foundation-prints-and-drawings',
#   'id': 'http://www.loc.gov/item/99400861/',
#   'item_id': None},
#  {'collection': 'gottscho-schleisner',
#   'id': 'http://www.loc.gov/item/gsc1994027942/PP/',
#   'item_id': None},
#  {'collection': 'grabill',
#   'id': 'http://www.loc.gov/item/89713369/',
#   'item_id': None},
#  {'collection': 'great-conversations-in-music',
#   'id': 'http://www.loc.gov/item/87752609/',
#   'item_id': '87752609/'},
#  {'collection': 'groups-of-images',
#   'id': 'http://www.loc.gov/item/19015344/',
#   'item_id': None},
#  {'collection': 'guide-records',
#   'id': 'http://www.loc.gov/item/2007685750/',
#   'item_id': None},
#  {'collection': 'harris-ewing',
#   'id': 'http://www.loc.gov/item/hec2013004043/',
#   'item_id': None},
#  {'collection': 'hidden-treasures-at-the-library-of-congress',
#   'id': 'http://www.loc.gov/collections/hidden-treasures-at-the-library-of-congress/articles-and-essays/meet-the-curators/',
#   'item_id': None},
#  {'collection': 'carol-m-highsmith',
#   'id': 'http://www.loc.gov/item/2015631182/',
#   'item_id': None},
#  {'collection': 'hispano-music-and-culture-from-the-northern-rio-grande',
#   'id': 'http://www.loc.gov/item/raelbib000006/',
#   'item_id': None},
#  {'collection': 'historic-american-buildings-landscapes-and-engineering-records',
#   'id': 'http://www.loc.gov/item/nj1346/',
#   'item_id': 'nj1346/'},
#  {'collection': 'historic-sheet-music',
#   'id': 'http://www.loc.gov/item/ihas.100004132/',
#   'item_id': 'ihas.100004132/'},
#  {'collection': 'music-of-nineteenth-century-ohio',
#   'id': 'http://www.loc.gov/item/ihas.200152821/',
#   'item_id': 'ihas.200152821/'},
#  {'collection': 'horydczak',
#   'id': 'http://www.loc.gov/item/thc1995002227/PP/',
#   'item_id': None},
#  {'collection': 'hotchkiss-maps',
#   'id': 'http://www.loc.gov/item/2005625263/',
#   'item_id': '2005625263/'},
#  {'collection': 'ilka-kolsky-artwork',
#   'id': 'http://www.loc.gov/collections/ilka-kolsky-artwork/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'indian-general-election-2009-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00093008/',
#   'item_id': None},
#  {'collection': 'indonesian-general-election-2009-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00092828/',
#   'item_id': None},
#  {'collection': 'films-of-westinghouse-works-1904',
#   'id': 'http://www.loc.gov/item/96521941/',
#   'item_id': None},
#  {'collection': 'international-tribunals-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0010099/',
#   'item_id': None},
#  {'collection': 'edison-company-motion-pictures-and-sound-recordings',
#   'id': 'http://www.loc.gov/item/00694225/',
#   'item_id': None},
#  {'collection': 'iraq-war-2003-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00010001/',
#   'item_id': None},
#  {'collection': 'irving-fine',
#   'id': 'http://www.loc.gov/collections/irving-fine/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'sheet-music-from-stage-and-screen',
#   'id': 'http://www.loc.gov/collections/sheet-music-from-stage-and-screen/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'james-k-polk-papers',
#   'id': 'http://www.loc.gov/collections/james-k-polk-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'james-madison-papers',
#   'id': 'http://www.loc.gov/item/mjm022764/',
#   'item_id': 'mjm022764/'},
#  {'collection': 'james-monroe-papers',
#   'id': 'http://www.loc.gov/item/mss33217002/',
#   'item_id': 'mss33217002/'},
#  {'collection': 'japanese-american-internment-camp-newspapers',
#   'id': 'http://www.loc.gov/item/sn84025955/1942-05-15/ed-1/',
#   'item_id': 'sn84025955/1942-05-15/ed-1/'},
#  {'collection': 'jazz-on-screen-filmography',
#   'id': 'http://www.loc.gov/collections/jazz-on-screen-filmography/about-this-collection/',
#   'item_id': None},
#  {'collection': 'jedediah-hotchkiss-papers',
#   'id': 'http://www.loc.gov/item/mss265260034/',
#   'item_id': 'mss265260034/'},
#  {'collection': 'joe-smith',
#   'id': 'http://www.loc.gov/item/jsmith000002/',
#   'item_id': None},
#  {'collection': 'john-pershing-papers',
#   'id': 'http://www.loc.gov/item/mss35949079/',
#   'item_id': 'mss35949079/'},
#  {'collection': 'john-tyler-papers',
#   'id': 'http://www.loc.gov/item/mss4348904/',
#   'item_id': 'mss4348904/'},
#  {'collection': 'frances-benjamin-johnston',
#   'id': 'http://www.loc.gov/item/2005689554/',
#   'item_id': None},
#  {'collection': 'korab',
#   'id': 'http://www.loc.gov/item/krb2008000127/',
#   'item_id': None},
#  {'collection': 'lamb-studio',
#   'id': 'http://www.loc.gov/item/2016676088/',
#   'item_id': None},
#  {'collection': 'laotian-general-election-2011-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00099409/',
#   'item_id': None},
#  {'collection': 'lars-schmidt',
#   'id': 'http://www.loc.gov/item/muslarsschmidt.200221538/',
#   'item_id': None},
#  {'collection': 'mckinley-and-the-pan-american-expo-films-1901',
#   'id': 'http://www.loc.gov/item/00694355/',
#   'item_id': None},
#  {'collection': 'lawrence-and-houseworth',
#   'id': 'http://www.loc.gov/item/2003674059/',
#   'item_id': None},
#  {'collection': 'legal-blawgs-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00090098/',
#   'item_id': None},
#  {'collection': 'legislative-branch-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0003448/',
#   'item_id': None},
#  {'collection': 'leonard-bernstein',
#   'id': 'http://www.loc.gov/item/lbypc.0152/',
#   'item_id': 'lbypc.0152/'},
#  {'collection': 'machen-family-papers',
#   'id': 'http://www.loc.gov/collections/machen-family-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'songs-of-america',
#   'id': 'http://www.loc.gov/item/ihas.100004132/',
#   'item_id': 'ihas.100004132/'},
#  {'collection': 'concerts-from-the-library-of-congress',
#   'id': 'http://www.loc.gov/item/99594334/',
#   'item_id': None},
#  {'collection': 'early-films-of-new-york-1898-to-1906',
#   'id': 'http://www.loc.gov/item/00694385/',
#   'item_id': None},
#  {'collection': 'liljenquist-civil-war-photographs',
#   'id': 'http://www.loc.gov/item/2010648383/',
#   'item_id': None},
#  {'collection': 'lomax',
#   'id': 'http://www.loc.gov/item/2007660150/',
#   'item_id': None},
#  {'collection': 'look-magazine',
#   'id': 'http://www.loc.gov/item/lbb1293/',
#   'item_id': None},
#  {'collection': 'louisiana-european-explorations-and-the-louisiana-purchase',
#   'id': 'http://www.loc.gov/item/01021531/',
#   'item_id': '01021531/'},
#  {'collection': 'manuscript-division-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00087412/',
#   'item_id': None},
#  {'collection': 'manuscripts-in-st-catherines-monastery-mount-sinai',
#   'id': 'http://www.loc.gov/item/00271070007-ms/',
#   'item_id': '00271070007-ms/'},
#  {'collection': 'greek-and-armenian-patriarchates-of-jerusalem',
#   'id': 'http://www.loc.gov/item/00271070494-jo/',
#   'item_id': '00271070494-jo/'},
#  {'collection': 'national-parks-maps',
#   'id': 'http://www.loc.gov/item/87690704/',
#   'item_id': None},
#  {'collection': 'maps-of-liberia-1830-to-1870',
#   'id': 'http://www.loc.gov/item/96684984/',
#   'item_id': None},
#  {'collection': 'john-philip-sousa',
#   'id': 'http://www.loc.gov/item/ihas.100003345/',
#   'item_id': 'ihas.100003345/'},
#  {'collection': 'margaret-bayard-smith-papers',
#   'id': 'http://www.loc.gov/collections/margaret-bayard-smith-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'martha-graham',
#   'id': 'http://www.loc.gov/item/ihas.200154367/',
#   'item_id': 'ihas.200154367/'},
#  {'collection': 'martin-van-buren-papers',
#   'id': 'http://www.loc.gov/item/mss438280006/',
#   'item_id': 'mss438280006/'},
#  {'collection': 'mary-ann-bickerdyke-papers',
#   'id': 'http://www.loc.gov/collections/mary-ann-bickerdyke-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'g-eric-and-edith-matson-photographs',
#   'id': 'http://www.loc.gov/item/mpc2005003471/PP/',
#   'item_id': None},
#  {'collection': 'military-battles-and-campaigns',
#   'id': 'http://www.loc.gov/item/02017602/',
#   'item_id': '02017602/'},
#  {'collection': 'millard-fillmore-papers',
#   'id': 'http://www.loc.gov/collections/millard-fillmore-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'moldenhauer-archives',
#   'id': 'http://www.loc.gov/collections/moldenhauer-archives/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'montana-folklife-survey-1979',
#   'id': 'http://www.loc.gov/item/afc1981005_10_22873/',
#   'item_id': 'afc1981005_10_22873/'},
#  {'collection': 'american-sheet-music-1820-to-1860',
#   'id': 'http://www.loc.gov/item/sm1834.010490/',
#   'item_id': 'sm1834.010490/'},
#  {'collection': 'american-sheet-music-1870-to-1885',
#   'id': 'http://www.loc.gov/item/sm1875.10894/',
#   'item_id': 'sm1875.10894/'},
#  {'collection': 'music-treasures-consortium',
#   'id': 'http://www.loc.gov/item/2009546928/',
#   'item_id': '2009546928/'},
#  {'collection': 'musical-instruments-at-the-library-of-congress',
#   'id': 'http://www.loc.gov/item/dcmphot.a0054/',
#   'item_id': None},
#  {'collection': 'nathan-w-daniels-diary-and-scrapbook',
#   'id': 'http://www.loc.gov/collections/nathan-w-daniels-diary-and-scrapbook/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'national-american-woman-suffrage-association',
#   'id': 'http://www.loc.gov/item/33001926/',
#   'item_id': '33001926/'},
#  {'collection': 'national-child-labor-committee',
#   'id': 'http://www.loc.gov/collections/national-child-labor-committee/about-this-collection/',
#   'item_id': None},
#  {'collection': 'national-photo-company',
#   'id': 'http://www.loc.gov/item/2004668297/',
#   'item_id': None},
#  {'collection': 'new-york-journal',
#   'id': 'http://www.loc.gov/item/sn83030429/1897-05-01/ed-1/',
#   'item_id': 'sn83030429/1897-05-01/ed-1/'},
#  {'collection': 'world-war-i-rotogravures',
#   'id': 'http://www.loc.gov/item/sn83030214/1916-01-02/ed-1/',
#   'item_id': 'sn83030214/1916-01-02/ed-1/'},
#  {'collection': 'blues-gospel-and-the-fort-valley-music-festivals',
#   'id': 'http://www.loc.gov/item/ftvbib000002/',
#   'item_id': None},
#  {'collection': 'occupational-folklife-project',
#   'id': 'http://www.loc.gov/item/2016655438/',
#   'item_id': None},
#  {'collection': 'omaha-indian-music',
#   'id': 'http://www.loc.gov/item/omhbib000464/',
#   'item_id': None},
#  {'collection': 'origins-of-american-animation',
#   'id': 'http://www.loc.gov/item/00694022/',
#   'item_id': None},
#  {'collection': 'panoramic-maps',
#   'id': 'http://www.loc.gov/item/map47000525/',
#   'item_id': None},
#  {'collection': 'panoramic-photographs',
#   'id': 'http://www.loc.gov/item/2007664633/',
#   'item_id': None},
#  {'collection': 'papal-transition-2005-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00085384/',
#   'item_id': None},
#  {'collection': 'patriotic-melodies',
#   'id': 'http://www.loc.gov/item/ihas.100000221/',
#   'item_id': None},
#  {'collection': 'ph-filing-series-photographs',
#   'id': 'http://www.loc.gov/item/2004673584/',
#   'item_id': None},
#  {'collection': 'philip-henry-sheridan-papers',
#   'id': 'http://www.loc.gov/item/mss397680719/',
#   'item_id': 'mss397680719/'},
#  {'collection': 'philippine-general-election-2010-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00095398/',
#   'item_id': None},
#  {'collection': 'phillips-mathee-collection',
#   'id': 'http://www.loc.gov/collections/phillips-mathee-collection/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'photochrom-prints',
#   'id': 'http://www.loc.gov/item/2002717350/',
#   'item_id': None},
#  {'collection': 'pioneering-the-upper-midwest',
#   'id': 'http://www.loc.gov/item/23014323/',
#   'item_id': '23014323/'},
#  {'collection': 'polish-declarations',
#   'id': 'http://www.loc.gov/collections/polish-declarations/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'popular-graphic-arts',
#   'id': 'http://www.loc.gov/collections/popular-graphic-arts/about-this-collection/',
#   'item_id': None},
#  {'collection': 'artists-posters',
#   'id': 'http://www.loc.gov/item/2008680351/',
#   'item_id': None},
#  {'collection': 'performing-arts-posters',
#   'id': 'http://www.loc.gov/item/2001697712/',
#   'item_id': None},
#  {'collection': 'spanish-civil-war-posters',
#   'id': 'http://www.loc.gov/item/99615716/',
#   'item_id': None},
#  {'collection': 'world-war-i-posters',
#   'id': 'http://www.loc.gov/item/2004666176/',
#   'item_id': None},
#  {'collection': 'works-progress-administration-posters',
#   'id': 'http://www.loc.gov/item/98518971/',
#   'item_id': None},
#  {'collection': 'yanker-posters',
#   'id': 'http://www.loc.gov/item/2015645632/',
#   'item_id': None},
#  {'collection': 'pre-1700-musical-treasures',
#   'id': 'http://www.loc.gov/item/2008561311/',
#   'item_id': '2008561311/'},
#  {'collection': 'broadsides-and-other-printed-ephemera',
#   'id': 'http://www.loc.gov/collections/broadsides-and-other-printed-ephemera/about-this-collection/',
#   'item_id': None},
#  {'collection': 'prokudin-gorskii',
#   'id': 'http://www.loc.gov/item/prk2000000280/',
#   'item_id': None},
#  {'collection': 'public-policy-topics-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00092763/',
#   'item_id': None},
#  {'collection': 'puerto-rico-books-and-pamphlets',
#   'id': 'http://www.loc.gov/item/30012858/',
#   'item_id': '30012858/'},
#  {'collection': 'quilts-and-quilt-making-in-america-from-1978-to-1996',
#   'id': 'http://www.loc.gov/item/qlt000392/',
#   'item_id': None},
#  {'collection': 'ragtime',
#   'id': 'http://www.loc.gov/item/ihas.200035774/',
#   'item_id': None},
#  {'collection': 'railroad-maps-1828-to-1900',
#   'id': 'http://www.loc.gov/item/98688300/',
#   'item_id': None},
#  {'collection': 'rare-book-selections',
#   'id': 'http://www.loc.gov/item/ltf89003468/',
#   'item_id': 'ltf89003468/'},
#  {'collection': 'rhode-island-folklife-project',
#   'id': 'http://www.loc.gov/item/afc1991022_01002/',
#   'item_id': 'afc1991022_01002/'},
#  {'collection': 'rochambeau-maps',
#   'id': 'http://www.loc.gov/item/gm71000980/',
#   'item_id': None},
#  {'collection': 'roger-reynolds',
#   'id': 'http://www.loc.gov/collections/roger-reynolds/about-this-collection/',
#   'item_id': None},
#  {'collection': 'roman-totenberg-papers',
#   'id': 'http://www.loc.gov/collections/roman-totenberg-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'totenberg-wilk',
#   'id': 'http://www.loc.gov/collections/totenberg-wilk/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'rosa-parks-papers',
#   'id': 'http://www.loc.gov/item/mss859430374/',
#   'item_id': 'mss859430374/'},
#  {'collection': 'salmon-p-chase-papers',
#   'id': 'http://www.loc.gov/item/mss156100027/',
#   'item_id': 'mss156100027/'},
#  {'collection': 'samuel-barber-at-the-library-of-congress',
#   'id': 'http://www.loc.gov/item/ihas.200035576/',
#   'item_id': 'ihas.200035576/'},
#  {'collection': 'samuel-morse-papers',
#   'id': 'http://www.loc.gov/collections/samuel-morse-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'samuel-j-gibson-papers',
#   'id': 'http://www.loc.gov/collections/samuel-j-gibson-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'sanborn-maps',
#   'id': 'http://www.loc.gov/collections/sanborn-maps/about-this-collection/how-to-view-maps/',
#   'item_id': None},
#  {'collection': 'katherine-dunham',
#   'id': 'http://www.loc.gov/item/2004672533/',
#   'item_id': None},
#  {'collection': 'september-11-2001-web-archive',
#   'id': 'http://www.loc.gov/item/006efe73358ac0d13069ea2716c73652/',
#   'item_id': None},
#  {'collection': 'september-11th-2001-documentary-project',
#   'id': 'http://www.loc.gov/item/afc911000228/',
#   'item_id': None},
#  {'collection': 'show-music-on-record',
#   'id': 'http://www.loc.gov/collections/show-music-on-record/articles-and-essays/',
#   'item_id': None},
#  {'collection': 'sigmund-freud-papers',
#   'id': 'http://www.loc.gov/collections/sigmund-freud-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'sikkim-photos',
#   'id': 'http://www.loc.gov/item/2011646250/',
#   'item_id': None},
#  {'collection': 'slaves-and-the-courts-from-1740-to-1860',
#   'id': 'http://www.loc.gov/item/18013203/',
#   'item_id': '18013203/'},
#  {'collection': 'small-press-expo-comic-and-comic-art-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0007142/',
#   'item_id': None},
#  {'collection': 'south-central-georgia-folklife-project',
#   'id': 'http://www.loc.gov/item/afc1982010_05_041/',
#   'item_id': 'afc1982010_05_041/'},
#  {'collection': 'john-and-ruby-lomax',
#   'id': 'http://www.loc.gov/item/lomaxbib000098/',
#   'item_id': None},
#  {'collection': 'spalding-base-ball-guides',
#   'id': 'http://www.loc.gov/item/spalding.00179/',
#   'item_id': 'spalding.00179/'},
#  {'collection': 'spanish-american-war-in-motion-pictures',
#   'id': 'http://www.loc.gov/item/98501077/',
#   'item_id': None},
#  {'collection': 'sports-byline',
#   'id': 'http://www.loc.gov/item/sports000001/',
#   'item_id': None},
#  {'collection': 'sri-lankan-presidential-and-general-elections-2010-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00094001/',
#   'item_id': None},
#  {'collection': 'stars-and-stripes',
#   'id': 'http://www.loc.gov/item/20001931/1918-02-15/ed-1/',
#   'item_id': '20001931/1918-02-15/ed-1/'},
#  {'collection': 'stereograph-cards',
#   'id': 'http://www.loc.gov/collections/stereograph-cards/about-this-collection/',
#   'item_id': None},
#  {'collection': 'folklife-and-landscape-in-southern-west-virginia',
#   'id': 'http://www.loc.gov/item/cmns001356/',
#   'item_id': None},
#  {'collection': 'thai-general-election-2011-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00099274/',
#   'item_id': None},
#  {'collection': 'theodore-roosevelt-films',
#   'id': 'http://www.loc.gov/item/mp76000001/',
#   'item_id': None},
#  {'collection': 'harned-whitman-collection',
#   'id': 'http://www.loc.gov/item/mss454430220/',
#   'item_id': 'mss454430220/'},
#  {'collection': 'thomas-jefferson-papers',
#   'id': 'http://www.loc.gov/item/mtjbib000204/',
#   'item_id': None},
#  {'collection': 'tibetan-oral-history-project',
#   'id': 'http://www.loc.gov/collections/tibetan-oral-history-project/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'timor-leste-2010-2011-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00094252/',
#   'item_id': None},
#  {'collection': 'tissandier',
#   'id': 'http://www.loc.gov/item/2002716361/',
#   'item_id': None},
#  {'collection': 'today-in-history',
#   'id': 'http://www.loc.gov/item/today-in-history/november-16/',
#   'item_id': None},
#  {'collection': 'transit-of-venus-march',
#   'id': 'http://www.loc.gov/collections/transit-of-venus-march/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'transportation-and-communication',
#   'id': 'http://www.loc.gov/item/95675177/',
#   'item_id': '95675177/'},
#  {'collection': 'united-states-code',
#   'id': 'http://www.loc.gov/collections/united-states-code/about-this-collection/rights-and-access/',
#   'item_id': None},
#  {'collection': 'ulysses-s-grant-papers',
#   'id': 'http://www.loc.gov/collections/ulysses-s-grant-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'united-states-congressional-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00hlgw00/',
#   'item_id': None},
#  {'collection': 'united-states-elections-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaE0000002/',
#   'item_id': None},
#  {'collection': 'van-vechten',
#   'id': 'http://www.loc.gov/item/2004662467/',
#   'item_id': None},
#  {'collection': 'vietnam-era-pow-mia-database',
#   'id': 'http://www.loc.gov/item/powmia/pw000001/',
#   'item_id': None},
#  {'collection': 'vietnamese-general-election-2011-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00099417/',
#   'item_id': None},
#  {'collection': 'visual-image-web-archive',
#   'id': 'http://www.loc.gov/item/lcwa00087410/',
#   'item_id': None},
#  {'collection': 'todd-and-sonkin-migrant-workers-from-1940-to-1941',
#   'id': 'http://www.loc.gov/collections/todd-and-sonkin-migrant-workers-from-1940-to-1941/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'walt-whitman-papers-mmc',
#   'id': 'http://www.loc.gov/collections/walt-whitman-papers-mmc/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'feinberg-whitman',
#   'id': 'http://www.loc.gov/collections/feinberg-whitman/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'warren-harding-carrie-fulton-phillips-correspondence',
#   'id': 'http://www.loc.gov/collections/warren-harding-carrie-fulton-phillips-correspondence/about-this-collection/provenance/',
#   'item_id': None},
#  {'collection': 'diary-of-horatio-taft',
#   'id': 'http://www.loc.gov/collections/diary-of-horatio-taft/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'web-cultures-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0009692/',
#   'item_id': None},
#  {'collection': 'webcomics-web-archive',
#   'id': 'http://www.loc.gov/item/lcwaN0009949/',
#   'item_id': None},
#  {'collection': 'wilbur-and-orville-wright-papers',
#   'id': 'http://www.loc.gov/item/wright002233/',
#   'item_id': 'wright002233/'},
#  {'collection': 'william-henry-harrison-papers',
#   'id': 'http://www.loc.gov/item/mss25148012/',
#   'item_id': 'mss25148012/'},
#  {'collection': 'jazz-photography-of-william-p-gottlieb',
#   'id': 'http://www.loc.gov/item/gottlieb.02761/',
#   'item_id': None},
#  {'collection': 'william-speiden-journals',
#   'id': 'http://www.loc.gov/collections/william-speiden-journals/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'william-t-sherman-papers',
#   'id': 'http://www.loc.gov/item/mss398000158/',
#   'item_id': 'mss398000158/'},
#  {'collection': 'winter-olympic-games-2002-web-archive',
#   'id': 'http://www.loc.gov/item/00027504dfe89a33fb8e13889f7db80d/',
#   'item_id': None},
#  {'collection': 'wm-oland-bourne-papers',
#   'id': 'http://www.loc.gov/collections/wm-oland-bourne-papers/about-this-collection/related-resources/',
#   'item_id': None},
#  {'collection': 'women-of-protest',
#   'id': 'http://www.loc.gov/item/mnwp000002/',
#   'item_id': None},
#  {'collection': 'woody-guthrie-correspondence-from-1940-to-1950',
#   'id': 'http://www.loc.gov/item/afcwwgbib000040/',
#   'item_id': None},
#  {'collection': 'working-in-paterson',
#   'id': 'http://www.loc.gov/item/afcwip000002/',
#   'item_id': None},
#  {'collection': 'world-war-i-sheet-music',
#   'id': 'http://www.loc.gov/item/2014561316/',
#   'item_id': '2014561316/'},
#  {'collection': 'world-war-ii-maps-military-situation-maps-from-1944-to-1945',
#   'id': 'http://www.loc.gov/collections/world-war-ii-maps-military-situation-maps-from-1944-to-1945/about-this-collection/',
#   'item_id': None},
#  {'collection': 'worlds-transportation-commission',
#   'id': 'http://www.loc.gov/item/2004707486/',
#   'item_id': None},
#  {'collection': 'wright-brothers-negatives',
#   'id': 'http://www.loc.gov/item/2001696267/',
#   'item_id': None},
#  {'collection': 'yiddish-american-popular-sheet-music',
#   'id': 'http://www.loc.gov/item/ihas.200154864/',
#   'item_id': 'ihas.200154864/'},
#  {'collection': 'zachary-taylor-papers',
#   'id': 'http://www.loc.gov/collections/zachary-taylor-papers/about-this-collection/',
#   'item_id': None},
#  {'collection': 'zora-neale-hurston-plays',
#   'id': 'http://www.loc.gov/collections/zora-neale-hurston-plays/about-this-collection/related-resources/',
#   'item_id': None}]

# %% [markdown]
# Let's use pandas to take a quick look at how many times each field is used.

# %%
import pandas as pd

# %%
collections_df = pd.DataFrame(id_fields_per_coll)
collections_df.count()
# Out:
# collection    290
# id            290
# item_id        76
# dtype: int64

# %% [markdown]
# OK, that confirms that all collections have an id field (which is the URL of the item), so going forward, we should **use the "id" field and not rely on "item_id"**.
#
# If we want to construct URLs that go to MODS records for a collection, then we need to grab the ID off the end of the URL in the "id" field. Here's an example of how to do that for the Baseball Cards collection. That's the collection I wanted to work with all along!

# %%
def get_ids(url, identifiers=[]):
    call = requests.get(url)
    data = call.json()
    results = data['results']
    for result in results:
        identifiers.append(result.get("id").split("/")[-2]) 
    if data["pagination"]["next"] is not None: # make sure we haven't hit the end of the pages
        next_url = data["pagination"]["next"]
        get_ids(next_url, identifiers)
        
    return identifiers

id_list = get_ids("https://www.loc.gov/collections/baseball-cards?fo=json")
id_list
# Out:
# ['about-this-collection',
#  '2007678540',
#  '2007678541',
#  '2007678542',
#  '2007678545',
#  '2007678537',
#  '2007678538',
#  '2007677698',
#  '2007680699',
#  '2007677699',
#  '2007680750',
#  '2007680759',
#  '2007680760',
#  '2007680761',
#  '2007680762',
#  '2007680763',
#  '2007680764',
#  '2007680765',
#  '2007680766',
#  '2007680767',
#  '2007680768',
#  '2007680751',
#  '2007680769',
#  '2007680771',
#  '2007680770',
#  '2007680772',
#  '2007680773',
#  '2007680774',
#  '2007680775',
#  '2007680776',
#  '2007680777',
#  '2007680778',
#  '2007680752',
#  '2007680779',
#  '2007680780',
#  '2007680781',
#  '2007680782',
#  '2007680783',
#  '2007680784',
#  '2007680785',
#  '2007680786',
#  '2007680787',
#  '2007680788',
#  '2007680753',
#  '2007680789',
#  '2007680790',
#  '2007680791',
#  '2007680792',
#  '2007680793',
#  '2007680794',
#  '2007680795',
#  '2007680796',
#  '2007680797',
#  '2007680798',
#  '2007680754',
#  '2007680799',
#  '2007680715',
#  '2007680716',
#  '2007680717',
#  '2007680718',
#  '2007680719',
#  '2007680720',
#  '2007680721',
#  '2007680722',
#  '2007680755',
#  '2007680756',
#  '2007680757',
#  '2007680758',
#  '2007680723',
#  '2007680724',
#  '2007680725',
#  '2007680726',
#  '2007680727',
#  '2007685599',
#  '2007685690',
#  '2007686506',
#  '2007686507',
#  '2007686508',
#  '2007686509',
#  '2007686510',
#  '2007686511',
#  '2007686512',
#  '2007686513',
#  '2007686514',
#  '2007686515',
#  '2007685691',
#  '2007686516',
#  '2007686517',
#  '2007686518',
#  '2007686519',
#  '2007686520',
#  '2007686521',
#  '2007686522',
#  '2007686523',
#  '2007686524',
#  '2007685692',
#  '2007686525',
#  '2007686526',
#  '2007686527',
#  '2007686528',
#  '2007686529',
#  '2007686530',
#  '2007686531',
#  '2007686532',
#  '2007686533',
#  '2007686534',
#  '2007685693',
#  '2007686535',
#  '2007686536',
#  '2007686537',
#  '2007686538',
#  '2007686539',
#  '2007686540',
#  '2007686541',
#  '2007686542',
#  '2007686543',
#  '2007686544',
#  '2007685694',
#  '2007686545',
#  '2007686546',
#  '2007686547',
#  '2007686548',
#  '2007686549',
#  '2007686414',
#  '2007686415',
#  '2007686416',
#  '2007686417',
#  '2007686550',
#  '2007685695',
#  '2007686551',
#  '2007686552',
#  '2007686553',
#  '2007686554',
#  '2007686555',
#  '2007686556',
#  '2007686557',
#  '2007686558',
#  '2007686559',
#  '2007686560',
#  '2007685696',
#  '2007686561',
#  '2007686562',
#  '2007686563',
#  '2007686564',
#  '2007686565',
#  '2007686566',
#  '2007686567',
#  '2007686568',
#  '2007686569',
#  '2007686570',
#  '2007685697',
#  '2007686571',
#  '2007686572',
#  '2007686573',
#  '2007686574',
#  '2007686575',
#  '2007686576',
#  '2007686577',
#  '2007686578',
#  '2007686579',
#  '2007686580',
#  '2007685698',
#  '2007686581',
#  '2007686582',
#  '2007686583',
#  '2007686584',
#  '2007686585',
#  '2007686586',
#  '2007686587',
#  '2007686588',
#  '2007686589',
#  '2007686590',
#  '2007685699',
#  '2007686591',
#  '2007686592',
#  '2007686593',
#  '2007686594',
#  '2007686595',
#  '2007686596',
#  '2007686597',
#  '2007686598',
#  '2007686599',
#  '2007686850',
#  '2007685742',
#  '2007685640',
#  '2007686851',
#  '2007686852',
#  '2007686853',
#  '2007686854',
#  '2007686855',
#  '2007686856',
#  '2007686857',
#  '2007686858',
#  '2007686859',
#  '2007686860',
#  '2007685641',
#  '2007686861',
#  '2007686862',
#  '2007686863',
#  '2007686864',
#  '2007686865',
#  '2007686866',
#  '2007686867',
#  '2007686868',
#  '2007686869',
#  '2007686870',
#  '2007685642',
#  '2007686871',
#  '2007686872',
#  '2007686873',
#  '2007686874',
#  '2007686875',
#  '2007686876',
#  '2007686877',
#  '2007686878',
#  '2007686879',
#  '2007686880',
#  '2007685643',
#  '2007686881',
#  '2007686882',
#  '2007686883',
#  '2007686884',
#  '2007686885',
#  '2007686886',
#  '2007686887',
#  '2007686888',
#  '2007686889',
#  '2007686890',
#  '2007685644',
#  '2007686891',
#  '2007686892',
#  '2007686893',
#  '2007686894',
#  '2007686895',
#  '2007686896',
#  '2007686897',
#  '2007686898',
#  '2007686899',
#  '2007686900',
#  '2007685645',
#  '2007686901',
#  '2007686902',
#  '2007686903',
#  '2007686904',
#  '2007686905',
#  '2007686906',
#  '2008678484',
#  '2007686908',
#  '2007686909',
#  '2007686910',
#  '2007685646',
#  '2007686911',
#  '2007686912',
#  '2007686913',
#  '2007686914',
#  '2007686915',
#  '2007686916',
#  '2007686917',
#  '2007686918',
#  '2007686919',
#  '2007686920',
#  '2007685647',
#  '2007686921',
#  '2007686922',
#  '2007686923',
#  '2007686924',
#  '2007686925',
#  '2007686926',
#  '2007686927',
#  '2007686928',
#  '2007686929',
#  '2007686930',
#  '2007685648',
#  '2007686931',
#  '2007686932',
#  '2007686933',
#  '2007686934',
#  '2007686935',
#  '2007686936',
#  '2007686937',
#  '2007686938',
#  '2007686939',
#  '2007686940',
#  '2007685649',
#  '2007686941',
#  '2007686942',
#  '2007686943',
#  '2007686944',
#  '2007686945',
#  '2007686946',
#  '2007686947',
#  '2007686948',
#  '2007686949',
#  '2007686418',
#  '2007685743',
#  '2007686400',
#  '2007686419',
#  '2007686420',
#  '2007686421',
#  '2007686422',
#  '2007686423',
#  '2007686424',
#  '2007686425',
#  '2007686950',
#  '2007686951',
#  '2007686952',
#  '2007686401',
#  '2007686953',
#  '2007686954',
#  '2007686955',
#  '2007686426',
#  '2007686956',
#  '2007686957',
#  '2007686958',
#  '2007686959',
#  '2007686960',
#  '2007686961',
#  '2007686402',
#  '2007686962',
#  '2007686963',
#  '2007686964',
#  '2007686965',
#  '2007686966',
#  '2007686967',
#  '2007686968',
#  '2007686969',
#  '2007686970',
#  '2007686971',
#  '2007686403',
#  '2007686972',
#  '2007686973',
#  '2007686974',
#  '2007686975',
#  '2007686976',
#  '2007686977',
#  '2007686978',
#  '2007686979',
#  '2007686980',
#  '2007686981',
#  '2007686404',
#  '2007686982',
#  '2007686983',
#  '2007686984',
#  '2007686985',
#  '2007686986',
#  '2007686987',
#  '2007686988',
#  '2007686989',
#  '2007686990',
#  '2007686991',
#  '2007686405',
#  '2007686992',
#  '2007686993',
#  '2007686994',
#  '2007686995',
#  '2007686996',
#  '2007686997',
#  '2007686998',
#  '2007686999',
#  '2008675052',
#  '2008675053',
#  '2007686406',
#  '2008675100',
#  '2008675101',
#  '2008675102',
#  '2008675103',
#  '2008675050',
#  '2008675104',
#  '2008675105',
#  '2008675106',
#  '2008675107',
#  '2008675108',
#  '2007686407',
#  '2008675109',
#  '2008675110',
#  '2008675111',
#  '2008675112',
#  '2008675113',
#  '2008675114',
#  '2008675115',
#  '2008675116',
#  '2008675117',
#  '2008675118',
#  '2007686408',
#  '2008675119',
#  '2008675120',
#  '2008675121',
#  '2008675122',
#  '2008675123',
#  '2008675124',
#  '2008675125',
#  '2008675126',
#  '2008675127',
#  '2008675128',
#  '2007686409',
#  '2008675129',
#  '2008675130',
#  '2008675051',
#  '2008675131',
#  '2008675132',
#  '2008675133',
#  '2008675134',
#  '2008675135',
#  '2008675136',
#  '2008675137',
#  '2007685744',
#  '2007686410',
#  '2008675138',
#  '2008675139',
#  '2008675140',
#  '2008675141',
#  '2008675142',
#  '2008675143',
#  '2008675144',
#  '2008675145',
#  '2008675146',
#  '2008675147',
#  '2007686411',
#  '2008675148',
#  '2008675149',
#  '2008675054',
#  '2008675055',
#  '2008675056',
#  '2008675057',
#  '2008675058',
#  '2008675059',
#  '2008675060',
#  '2008675061',
#  '2007686412',
#  '2008675062',
#  '2008675063',
#  '2008675064',
#  '2008675065',
#  '2008675066',
#  '2008675067',
#  '2008675068',
#  '2008675069',
#  '2008675070',
#  '2008675071',
#  '2007686413',
#  '2008675072',
#  '2008675073',
#  '2008675074',
#  '2008675075',
#  '2008675076',
#  '2008675077',
#  '2008675078',
#  '2008675079',
#  '2008675080',
#  '2008675081',
#  '2007686450',
#  '2008675082',
#  '2008675083',
#  '2008675084',
#  '2008675085',
#  '2008675086',
#  '2008675087',
#  '2008675088',
#  '2008675089',
#  '2008675090',
#  '2008675091',
#  '2007686451',
#  '2008675200',
#  '2008675201',
#  '2008675202',
#  '2008675203',
#  '2008675204',
#  '2008675205',
#  '2008675206',
#  '2008675207',
#  '2008675208',
#  '2008675209',
#  '2007686452',
#  '2008675210',
#  '2008675211',
#  '2008675212',
#  '2008675213',
#  '2008675214',
#  '2008675215',
#  '2008675216',
#  '2008675217',
#  '2008675218',
#  '2008675219',
#  '2007686453',
#  '2008675220',
#  '2008675221',
#  '2008675222',
#  '2008675223',
#  '2008675224',
#  '2008675225',
#  '2008675226',
#  '2008675227',
#  '2007686454',
#  '2007686455',
#  '2007685745',
#  '2007686456',
#  '2007686457',
#  '2007686458',
#  '2007686459',
#  '2007686460',
#  '2007686461',
#  '2007686462',
#  '2007686463',
#  '2007686464',
#  '2007686465',
#  '2007685746',
#  '2007686466',
#  '2007686467',
#  '2007686468',
#  '2007686469',
#  '2007686470',
#  '2007686471',
#  '2007686472',
#  '2007686473',
#  '2007686474',
#  '2007686475',
#  '2007685747',
#  '2007686476',
#  '2007686477',
#  '2007686478',
#  '2007686479',
#  '2007686480',
#  '2007686481',
#  '2007686482',
#  '2007686483',
#  '2007686484',
#  '2007686485',
#  '2007685748',
#  '2007686486',
#  '2007686487',
#  '2007686488',
#  '2007686489',
#  '2007686490',
#  '2007686491',
#  '2007686492',
#  '2007686493',
#  '2007686494',
#  '2007686495',
#  '2007685749',
#  '2007686496',
#  '2007686497',
#  '2007686498',
#  '2007686499',
#  '2007686500',
#  '2007686501',
#  '2007686502',
#  '2007686503',
#  '2007686504',
#  '2007686505',
#  '2007680728',
#  '2007680729',
#  '2007680730',
#  '2007680731',
#  '2007680732',
#  '2007680733',
#  '2007680734',
#  '2007680735',
#  '2007680736',
#  '2007680737',
#  '2007680738',
#  '2007680739',
#  '2007680740',
#  '2007680741',
#  '2007680742',
#  '2007680743',
#  '2007680744',
#  '2007680745',
#  '2007680746',
#  '2007680747',
#  '2007680748',
#  '2007680749',
#  '2007683700',
#  '2007683701',
#  '2007683702',
#  '2007683703',
#  '2007683704',
#  '2007683705',
#  '2007683706',
#  '2007683750',
#  '2007683759',
#  '2007683760',
#  '2007683761',
#  '2007683762',
#  '2007683763',
#  '2007683764',
#  '2007683765',
#  '2007683766',
#  '2007683767',
#  '2007683768',
#  '2007683751',
#  '2007683769',
#  '2007683770',
#  '2007683771',
#  '2007683772',
#  '2007683773',
#  '2007683774',
#  '2007683775',
#  '2007683752',
#  '2007683753',
#  '2007683754',
#  '2007683755',
#  '2007683756',
#  '2007683757',
#  '2007683758',
#  '2007683776',
#  '2007683777',
#  '2007683707',
#  '2007683708',
#  '2007683709',
#  '2007683710',
#  '2007683719',
#  '2007683720',
#  '2007683721',
#  '2007683722',
#  '2007683723',
#  '2007683711',
#  '2007683712',
#  '2007683713',
#  '2007683714',
#  '2007683715',
#  '2007683716',
#  '2007683717',
#  '2007683718',
#  '2007683724',
#  '2007683733',
#  '2007683734',
#  '2007683735',
#  '2007683736',
#  '2007683737',
#  '2007683738',
#  '2007683739',
#  '2007683740',
#  '2007683741',
#  '2007683742',
#  '2007683725',
#  '2007683743',
#  '2007683744',
#  '2007683745',
#  '2007683746',
#  '2007683747',
#  '2007683748',
#  '2007683749',
#  '2007683778',
#  '2007683779',
#  '2007683780',
#  '2007683726',
#  '2007683781',
#  '2007683782',
#  '2007683783',
#  '2007683784',
#  '2007683785',
#  '2007683786',
#  '2007683787',
#  '2007683788',
#  '2007683789',
#  '2007683790',
#  '2007683727',
#  '2007683791',
#  '2007683792',
#  '2007683793',
#  '2007683794',
#  '2007683795',
#  '2007683796',
#  '2007683797',
#  '2007683798',
#  '2007683799',
#  '2007683850',
#  '2007683728',
#  '2007683851',
#  '2007683852',
#  '2007683853',
#  '2007683854',
#  '2007683855',
#  '2007683856',
#  '2007683729',
#  '2007683730',
#  '2007683731',
#  '2007683732',
#  '2008675092',
#  '2008675235',
#  '2008676469',
#  '2008676470',
#  '2008676471',
#  '2008676472',
#  '2008676473',
#  '2008676474',
#  '2008676475',
#  '2008676476',
#  '2008676477',
#  '2008676478',
#  '2008675236',
#  '2008676479',
#  '2008676480',
#  '2008676481',
#  '2008676482',
#  '2008676483',
#  '2008676484',
#  '2008676485',
#  '2008676486',
#  '2008676487',
#  '2008676488',
#  '2008675237',
#  '2008676489',
#  '2008676490',
#  '2008676491',
#  '2008676492',
#  '2008675155',
#  '2008676493',
#  '2008676494',
#  '2008676495',
#  '2008676496',
#  '2008676497',
#  '2008675238',
#  '2008676498',
#  '2008676499',
#  '2008676500',
#  '2008676501',
#  '2008676502',
#  '2008675173',
#  '2008676503',
#  '2008676504',
#  '2008676505',
#  '2008676506',
#  '2008675239',
#  '2008676507',
#  '2008676508',
#  '2008676509',
#  '2008676510',
#  '2008676511',
#  '2008676512',
#  '2008676513',
#  '2008676514',
#  '2008676515',
#  '2008676516',
#  '2008675240',
#  '2008676517',
#  '2008676518',
#  '2008676519',
#  '2008676520',
#  '2008676521',
#  '2008676522',
#  '2008676523',
#  '2008676524',
#  '2008676525',
#  '2008676526',
#  '2008675241',
#  '2008676527',
#  '2008676528',
#  '2008676529',
#  '2008676530',
#  '2008676531',
#  '2008676532',
#  '2008676533',
#  '2008676534',
#  '2008676535',
#  '2008676536',
#  '2008675242',
#  '2008676537',
#  '2008676538',
#  '2008676539',
#  '2008676540',
#  '2008676541',
#  '2008676542',
#  '2008676543',
#  '2008676544',
#  '2008676545',
#  '2008676546',
#  '2008675094',
#  '2008676547',
#  '2008676548',
#  '2008676549',
#  '2008676406',
#  '2008676407',
#  '2008676408',
#  '2008676409',
#  '2008676410',
#  '2008676411',
#  '2008676412',
#  '2008675095',
#  '2008676413',
#  '2008676414',
#  '2008676415',
#  '2008676416',
#  '2008676417',
#  '2008676418',
#  '2008676419',
#  '2008676420',
#  '2008676421',
#  '2008676422',
#  '2008675228',
#  '2008675096',
#  '2008676423',
#  '2008676424',
#  '2008676425',
#  '2008676426',
#  '2008676427',
#  '2008676428',
#  '2008676429',
#  '2008676430',
#  '2008676431',
#  '2008676432',
#  '2008675097',
#  '2008676433',
#  '2008676434',
#  '2008676435',
#  '2008676436',
#  '2008676437',
#  '2008676438',
#  '2008676439',
#  '2008676440',
#  '2008676441',
#  '2008676442',
#  '2008675098',
#  '2008676443',
#  '2008676444',
#  '2008676445',
#  '2008676446',
#  '2008676447',
#  '2008676448',
#  '2008676449',
#  '2008676600',
#  '2008676601',
#  '2008676602',
#  '2008675243',
#  '2008676603',
#  '2008676604',
#  '2008676605',
#  '2008676606',
#  '2008676607',
#  '2008676608',
#  '2008676609',
#  '2008676610',
#  '2008676611',
#  '2008676612',
#  '2008675244',
#  '2008676550',
#  '2008676551',
#  '2008676552',
#  '2008676553',
#  '2008676554',
#  '2008676555',
#  '2008676556',
#  '2008676557',
#  '2008676558',
#  '2008676559',
#  '2008675245',
#  '2008676560',
#  '2008676561',
#  '2008676562',
#  '2008676563',
#  '2008676564',
#  '2008676565',
#  '2008676566',
#  '2008676567',
#  '2008676568',
#  '2008676569',
#  '2008675246',
#  '2008676570',
#  '2008676571',
#  '2008676572',
#  '2008676573',
#  '2008676574',
#  '2008676575',
#  '2008676576',
#  '2008676577',
#  '2008676578',
#  '2008676579',
#  '2008675247',
#  '2008676580',
#  '2008675174',
#  '2008676581',
#  '2008676582',
#  '2008676583',
#  '2008676584',
#  '2008676585',
#  '2008676586',
#  '2008676587',
#  '2008676588',
#  '2008675248',
#  '2008676589',
#  '2008676590',
#  '2008676591',
#  '2008676592',
#  '2008676593',
#  '2008676594',
#  '2008676595',
#  '2008676596',
#  '2008676597',
#  '2008676598',
#  '2008675249',
#  '2008676599',
#  '2008676613',
#  '2008676614',
#  '2008676615',
#  '2008676800',
#  '2008676801',
#  '2008676802',
#  '2008676803',
#  '2008676804',
#  '2008676805',
#  '2008675229',
#  '2008675157',
#  '2008676806',
#  '2008676807',
#  '2008676808',
#  '2008676809',
#  '2008676810',
#  '2008676811',
#  '2008676812',
#  '2008675175',
#  '2008676813',
#  '2008676814',
#  '2008675158',
#  '2008676815',
#  '2008676816',
#  '2008676817',
#  '2008676818',
#  '2008676819',
#  '2008676820',
#  '2008676821',
#  '2008676822',
#  '2008676823',
#  '2008676824',
#  '2008675159',
#  '2008676825',
#  '2008676826',
#  '2008676827',
#  '2008676828',
#  '2008676829',
#  '2008676830',
#  '2008676831',
#  '2008676832',
#  '2008676833',
#  '2008676834',
#  '2008675099',
#  '2008676835',
#  '2008676836',
#  '2008676837',
#  '2008676838',
#  '2008676839',
#  '2008676840',
#  '2008676841',
#  '2008676842',
#  '2008676843',
#  '2008676844',
#  '2008675160',
#  '2008676845',
#  '2008676846',
#  '2008676847',
#  '2008676848',
#  '2008676849',
#  '2008676616',
#  '2008676617',
#  '2008676618',
#  '2008676619',
#  '2008676620',
#  '2008675161',
#  '2008676621',
#  '2008676622',
#  '2008676623',
#  '2008676625',
#  '2008676626',
#  '2008676627',
#  '2008676628',
#  '2008676629',
#  '2008676630',
#  '2008675162',
#  '2008676631',
#  '2008676632',
#  '2008676633',
#  '2008676634',
#  '2008676635',
#  '2008676636',
#  '2008676637',
#  '2008676638',
#  '2008676639',
#  '2008676640',
#  '2008675163',
#  '2008676641',
#  '2008676642',
#  '2008676850',
#  '2008676851',
#  '2008676852',
#  '2008676853',
#  '2008676854',
#  '2008676855',
#  '2008676856',
#  '2008676857',
#  '2008675164',
#  '2008676858',
#  '2008676859',
#  '2008676860',
#  '2008676861',
#  '2008676862',
#  '2008676863',
#  '2008676864',
#  '2008675176',
#  '2008676865',
#  '2008676866',
#  '2008675150',
#  ...]

# %% [markdown]
# ## Takeaways:
# * If someone wants to use the API to get the info needed to request MODS/MARCXML/Dublin Core records for items from a collection, they're going to need the identifiers of the items in a collection. I'm not really sure what's in those records that's not in the API data, though, to be honest. But those other formats might facilitate bring together data from other sources that also provide their data in MODS/MARCXML/DC.
# * Ideally, all of the collections that come back in an API request for collections would have item data available via the API, so you don't have to go through and exclude certain collections. I understand that's a work in progress. So, in the meantime, perhaps:
#   * Indicate whether a collection is available via the API (a separate field?) or don't include it at all.
#   * Add item_id to all of the available collections so it's easier to grab it for constructing further URLs.
# * Consider providing a field with the slug for collection name-- might make it easier to construct further URLs for retrieving data.
# * The web page for an item provides links to MODS/MARCXML/Dublin Core records if they're available. But those links aren't returned in the API, or at least I couldn't find anything like that. If there's a way to determine whether those formats are available and/or provide links to those records, that could be useful for this sort of project.
